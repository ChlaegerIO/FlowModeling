# %% [markdown]
# Dog vs. Cats example

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
from torchvision import datasets, transforms
from tqdm import tqdm
import time

     # display progress



kwargs = {}          # without GPU
#kwargs = {'num_workers': 1, 'pin_memory': True}        # with GPU
train_data = torch.utils.data.DataLoader(datasets.MNIST('data_figures_nn', train=True, download=True, 
                                                    transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,),(0.3082,))])),
                                    batch_size=64, shuffle=True, **kwargs)    # shuffle that network don't learns repetition, kwargs are arguments for the function (has to be written)  

test_data = torch.utils.data.DataLoader(datasets.MNIST('data_figures_nn', train=False, download=True, 
                                                    transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,),(0.3082,))])),
                                    batch_size=64, shuffle=True, **kwargs)    # shuffle that network don't learns repetition, kwargs are arguments for the function (has to be written)  

class net(nn.Module):
    def __init__(self):
        super(net, self).__init__()
        # definition of object layers
        self.conv1 = nn.Conv2d(1,10,kernel_size=5)    # (in_channels: Eingangsdimension, out_channels: Ausgangsdimension)
        # (kernel_size: Faltungsfiltergrösse, stride: #Schritte der Faltung (reduziert Dimension), padding: Leerer Rand dass Dimension weniger abnimmt, dilation: adding zeros between kernel, groups: , bias: added to output, padding_mode='zeros')
        self.conv2 = nn.Conv2d(10,20,kernel_size=5)
        # (p=0.5: probability for dropout, inplace: if True input layer gets changed)
        self.conv_dropout = nn.Dropout2d()            # damit das Netz nichts auswendig lernt
        self.fc1 = nn.Linear(320, 60)
        self.fc2 = nn.Linear(60, 10)
    
    def forward(self,x):
        # actual layer composition
        #print('start:',x.shape)
        x = self.conv1(x)
        #print('conv1:', x.shape)
        # (kernel_size, stride, padding, dilation, return_indices: of max value if True, ceil_mode: ceil if True (aufrunden))
        x = F.max_pool2d(x, 2)
        #print('pool1:', x.shape)
        x = F.relu(x)
        #print('relu1:',x.shape)
        x = self.conv2(x)
        #print('conv2:',x.shape)
        x = self.conv_dropout(x)
        #print('dropout:',x.shape)
        x = F.max_pool2d(x, 2)
        #print('pool2:',x.shape)
        x = F.relu(x)
        #print('relu2:', x.shape)
        x = x.view(-1,320)        # daten umformen
        #print('view:', x.shape)
        x = F.relu(self.fc1(x))
        #print('relu3_fc1:', x.shape)
        x = self.fc2(x)
        #print('fc2:', x.shape)
        
        return F.log_softmax(x)
        

# model
model = net()
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.8)   # momentum [0,1]

# training
def train(epoch):
    model.train()
    #model.eval()
    # in our train data we have the pictures (data), target number 1-9 and bates of size 64 in this case
    for batch_id, (data, target) in enumerate(train_data):
        with tqdm(train_data, unit="batch") as tepoch:
            #data = data.cuda()
            #target = target.cuda()
            #data = Variable(data)
            #target = Variable(target)
            optimizer.zero_grad()
            # forward pass
            out = model(data)
            #calculate loss
            loss = F.nll_loss(out, target)          # nn.CrossEntropyLoss(), F.nll_loss is better
            #loss = criterion(out, target)
            loss.backward()
            optimizer.step()
            #print('Train Epoche: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                #epoch,batch_id*len(data), len(train_data.dataset), 100. * batch_id / len(train_data), loss.item()))
            # display training progress
            tepoch.set_description(f"Epoch {epoch}")
            accuracy = 100. * batch_id / len(train_data)
            tepoch.set_postfix(loss=loss.item(), accuracy=100. * accuracy)
            time.sleep(0.1)
            torch.save(net, 'data_figures_nn/MyNet_MNIST.pt')

        
for epoch in range(1,30):

        train(epoch)
# Out:
#   0%|                                                                                       | 0/938 [00:00<?, ?batch/s]C:\Users\timok\AppData\Local\Temp/ipykernel_24312/83000891.py:61: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# Epoch 1:   0%|                                                       | 0/938 [00:00<?, ?batch/s, accuracy=0, loss=2.31]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=10.7, loss=2.3]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=21.3, loss=2.31]
# Epoch 1:   0%|                                                      | 0/938 [00:00<?, ?batch/s, accuracy=32, loss=2.26]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=42.6, loss=2.27]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=53.3, loss=2.3]
# Epoch 1:   0%|                                                      | 0/938 [00:00<?, ?batch/s, accuracy=64, loss=2.22]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=74.6, loss=2.21]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=85.3, loss=2.16]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=95.9, loss=2.09]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=107, loss=1.94]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=117, loss=2.03]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=128, loss=1.93]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=139, loss=1.68]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=149, loss=1.63]
# Epoch 1:   0%|                                                      | 0/938 [00:00<?, ?batch/s, accuracy=160, loss=1.3]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=171, loss=1.57]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=181, loss=1.22]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=192, loss=1.31]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=203, loss=1.25]
# Epoch 1:   0%|                                                      | 0/938 [00:00<?, ?batch/s, accuracy=213, loss=1.2]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=224, loss=0.856]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=235, loss=1.39]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=245, loss=1.06]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=256, loss=0.832]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=267, loss=0.674]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=277, loss=0.674]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=288, loss=0.971]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=299, loss=0.847]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=309, loss=0.919]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=320, loss=1.19]
# Epoch 1:   0%|                                                      | 0/938 [00:00<?, ?batch/s, accuracy=330, loss=0.7]
# Epoch 1:   0%|                                                    | 0/938 [00:00<?, ?batch/s, accuracy=341, loss=0.868]
# Epoch 1:   0%|                                                     | 0/938 [00:00<?, ?batch/s, accuracy=352, loss=1.05]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24312/83000891.py in <module>
#      97 for epoch in range(1,30):
#      98
# ---> 99         train(epoch)
#
# ~\AppData\Local\Temp/ipykernel_24312/83000891.py in train(epoch)
#      91             accuracy = 100. * batch_id / len(train_data)
#      92             tepoch.set_postfix(loss=loss.item(), accuracy=100. * accuracy)
# ---> 93             time.sleep(0.1)
#      94             torch.save(net, 'data_figures_nn/MyNet_MNIST.pt')
#      95
#
# KeyboardInterrupt:

# %%
# dogs vs. cats
dogdata_w_mat = io.loadmat(os.path.join('..','DATA','dogData_w.mat'))
catdata_w_mat = io.loadmat(os.path.join('..','DATA','catData_w.mat'))

dog_wave = dogdata_w_mat['dog_wave']
cat_wave = catdata_w_mat['cat_wave']

CD = np.concatenate((dog_wave,cat_wave),axis=1)

train = np.concatenate((dog_wave[:,:60],cat_wave[:,:60]),axis=1)
test = np.concatenate((dog_wave[:,60:80],cat_wave[:,60:80]),axis=1)
label = np.repeat(np.array([1,-1]),60)

A = label @ np.linalg.pinv(train)
test_labels = np.sign(A@test)

# %%
from tqdm import trange
from time import sleep

def get_divisors(n):
    divisors = []
    for m in range(1, n+1):
        if n % m == 0:
            divisors.append(m)
    return divisors

iterations = 10
with trange(iterations, unit="carrots") as pbar:
    for i in pbar:
        sleep(0.5)
        if i % 2:
            pbar.set_description(f"Testing odd number {i}")
        else:
            pbar.set_description(f"Testing even number {i}")
        pbar.set_postfix(divisors=get_divisors(i))
# Out:
# Testing odd number 9: 100%|███████████████████████████████████| 10/10 [00:05<00:00,  1.97carrots/s, divisors=[1, 3, 9]]

# %%
# example
def rmse(y, y_hat):
    """Compute root mean squared error"""
    return torch.sqrt(torch.mean((y - y_hat).pow(2)))

def forward(x, e):
    """Forward pass for our fuction"""
    return x.pow(e.repeat(x.size(0)))

# Let's define some settings
n = 1000 # number of examples
learning_rate = 5e-10

# Model parameters
exp = Variable(torch.FloatTensor([2.0]), requires_grad=False)
exp_hat = Variable(torch.FloatTensor([8]), requires_grad=True)

# Model definition
x = Variable(torch.rand(n) * 10, requires_grad=False)
y = forward(x, exp)


# Optimizer (NEW)
opt = torch.optim.SGD([exp_hat], lr=learning_rate, momentum=0.9)

loss_history = []
exp_history = []

# Training loop
for i in range(0, 10000):
    opt.zero_grad()
    print("Iteration %d" % i)
    
    # Compute current estimate
    y_hat = forward(x, exp_hat)
    
    # Calculate loss function
    loss = rmse(y, y_hat)
    
    # Do some recordings for plots
    loss_history.append(loss.item())
    exp_history.append(y_hat.data[0])
    
    # Update model parameters
    loss.backward()
    opt.step()
    
    print("loss = %s" % loss.item())
    print("exp = %s" % exp_hat.data[0])
# Out:
# Iteration 0
# loss = 26091824.0
# exp = tensor(7.9706)
# Iteration 1
# loss = 24421982.0
# exp = tensor(7.9167)
# Iteration 2
# loss = 21629796.0
# exp = tensor(7.8438)
# Iteration 3
# loss = 18357172.0
# exp = tensor(7.7576)
# Iteration 4
# loss = 15118497.0
# exp = tensor(7.6629)
# Iteration 5
# loss = 12219175.0
# exp = tensor(7.5640)
# Iteration 6
# loss = 9781847.0
# exp = tensor(7.4640)
# Iteration 7
# loss = 7811741.5
# exp = tensor(7.3652)
# Iteration 8
# loss = 6256015.0
# exp = tensor(7.2692)
# Iteration 9
# loss = 5042654.5
# exp = tensor(7.1772)
# Iteration 10
# loss = 4100948.75
# exp = tensor(7.0898)
# Iteration 11
# loss = 3369918.5
# exp = tensor(7.0073)
# Iteration 12
# loss = 2800368.75
# exp = tensor(6.9300)
# Iteration 13
# loss = 2354008.75
# exp = tensor(6.8577)
# Iteration 14
# loss = 2001641.375
# exp = tensor(6.7904)
# Iteration 15
# loss = 1721217.5
# exp = tensor(6.7279)
# Iteration 16
# loss = 1496149.25
# exp = tensor(6.6700)
# Iteration 17
# loss = 1313950.75
# exp = tensor(6.6164)
# Iteration 18
# loss = 1165198.75
# exp = tensor(6.5669)
# Iteration 19
# loss = 1042743.6875
# exp = tensor(6.5211)
# Iteration 20
# loss = 941128.1875
# exp = tensor(6.4789)
# Iteration 21
# loss = 856158.8125
# exp = tensor(6.4399)
# Iteration 22
# loss = 784589.3125
# exp = tensor(6.4039)
# Iteration 23
# loss = 723889.5
# exp = tensor(6.3708)
# Iteration 24
# loss = 672071.4375
# exp = tensor(6.3402)
# Iteration 25
# loss = 627561.9375
# exp = tensor(6.3119)
# Iteration 26
# loss = 589106.8125
# exp = tensor(6.2858)
# Iteration 27
# loss = 555699.1875
# exp = tensor(6.2618)
# Iteration 28
# loss = 526524.6875
# exp = tensor(6.2395)
# Iteration 29
# loss = 500920.84375
# exp = tensor(6.2189)
# Iteration 30
# loss = 478345.4375
# exp = tensor(6.1998)
# Iteration 31
# loss = 458351.0625
# exp = tensor(6.1821)
# Iteration 32
# loss = 440567.59375
# exp = tensor(6.1657)
# Iteration 33
# loss = 424685.59375
# exp = tensor(6.1504)
# Iteration 34
# loss = 410446.71875
# exp = tensor(6.1363)
# Iteration 35
# loss = 397632.5
# exp = tensor(6.1231)
# Iteration 36
# loss = 386058.625
# exp = tensor(6.1107)
# Iteration 37
# loss = 375568.15625
# exp = tensor(6.0992)
# Iteration 38
# loss = 366027.0625
# exp = tensor(6.0885)
# Iteration 39
# loss = 357320.875
# exp = tensor(6.0784)
# Iteration 40
# loss = 349350.34375
# exp = tensor(6.0689)
# Iteration 41
# loss = 342030.71875
# exp = tensor(6.0600)
# Iteration 42
# loss = 335287.375
# exp = tensor(6.0516)
# Iteration 43
# loss = 329056.65625
# exp = tensor(6.0437)
# Iteration 44
# loss = 323282.3125
# exp = tensor(6.0362)
# Iteration 45
# loss = 317915.0625
# exp = tensor(6.0291)
# Iteration 46
# loss = 312912.21875
# exp = tensor(6.0224)
# Iteration 47
# loss = 308235.90625
# exp = tensor(6.0160)
# Iteration 48
# loss = 303853.0625
# exp = tensor(6.0099)
# Iteration 49
# loss = 299734.21875
# exp = tensor(6.0040)
# Iteration 50
# loss = 295853.5
# exp = tensor(5.9985)
# Iteration 51
# loss = 292187.90625
# exp = tensor(5.9931)
# Iteration 52
# loss = 288716.96875
# exp = tensor(5.9880)
# Iteration 53
# loss = 285422.4375
# exp = tensor(5.9831)
# Iteration 54
# loss = 282288.3125
# exp = tensor(5.9783)
# Iteration 55
# loss = 279300.0
# exp = tensor(5.9737)
# Iteration 56
# loss = 276444.6875
# exp = tensor(5.9692)
# Iteration 57
# loss = 273710.84375
# exp = tensor(5.9649)
# Iteration 58
# loss = 271088.09375
# exp = tensor(5.9608)
# Iteration 59
# loss = 268567.25
# exp = tensor(5.9567)
# Iteration 60
# loss = 266139.96875
# exp = tensor(5.9527)
# Iteration 61
# loss = 263798.71875
# exp = tensor(5.9489)
# Iteration 62
# loss = 261536.9375
# exp = tensor(5.9451)
# Iteration 63
# loss = 259348.46875
# exp = tensor(5.9415)
# Iteration 64
# loss = 257227.96875
# exp = tensor(5.9379)
# Iteration 65
# loss = 255170.515625
# exp = tensor(5.9343)
# Iteration 66
# loss = 253171.359375
# exp = tensor(5.9309)
# Iteration 67
# loss = 251226.71875
# exp = tensor(5.9275)
# Iteration 68
# loss = 249332.921875
# exp = tensor(5.9242)
# Iteration 69
# loss = 247486.640625
# exp = tensor(5.9209)
# Iteration 70
# loss = 245684.703125
# exp = tensor(5.9177)
# Iteration 71
# loss = 243924.765625
# exp = tensor(5.9145)
# Iteration 72
# loss = 242204.015625
# exp = tensor(5.9114)
# Iteration 73
# loss = 240520.28125
# exp = tensor(5.9083)
# Iteration 74
# loss = 238871.46875
# exp = tensor(5.9053)
# Iteration 75
# loss = 237255.71875
# exp = tensor(5.9023)
# Iteration 76
# loss = 235671.25
# exp = tensor(5.8993)
# Iteration 77
# loss = 234116.59375
# exp = tensor(5.8964)
# Iteration 78
# loss = 232590.0625
# exp = tensor(5.8935)
# Iteration 79
# loss = 231090.46875
# exp = tensor(5.8906)
# Iteration 80
# loss = 229616.734375
# exp = tensor(5.8878)
# Iteration 81
# loss = 228167.734375
# exp = tensor(5.8850)
# Iteration 82
# loss = 226742.125
# exp = tensor(5.8822)
# Iteration 83
# loss = 225339.15625
# exp = tensor(5.8795)
# Iteration 84
# loss = 223957.984375
# exp = tensor(5.8767)
# Iteration 85
# loss = 222597.625
# exp = tensor(5.8740)
# Iteration 86
# loss = 221257.578125
# exp = tensor(5.8714)
# Iteration 87
# loss = 219936.859375
# exp = tensor(5.8687)
# Iteration 88
# loss = 218634.984375
# exp = tensor(5.8661)
# Iteration 89
# loss = 217351.25
# exp = tensor(5.8635)
# Iteration 90
# loss = 216085.203125
# exp = tensor(5.8609)
# Iteration 91
# loss = 214836.171875
# exp = tensor(5.8583)
# Iteration 92
# loss = 213603.671875
# exp = tensor(5.8557)
# Iteration 93
# loss = 212387.328125
# exp = tensor(5.8532)
# Iteration 94
# loss = 211186.46875
# exp = tensor(5.8507)
# Iteration 95
# loss = 210000.90625
# exp = tensor(5.8482)
# Iteration 96
# loss = 208830.265625
# exp = tensor(5.8457)
# Iteration 97
# loss = 207673.890625
# exp = tensor(5.8432)
# Iteration 98
# loss = 206531.640625
# exp = tensor(5.8408)
# Iteration 99
# loss = 205403.109375
# exp = tensor(5.8383)
# Iteration 100
# loss = 204287.953125
# exp = tensor(5.8359)
# Iteration 101
# loss = 203186.0
# exp = tensor(5.8335)
# Iteration 102
# loss = 202096.875
# exp = tensor(5.8311)
# Iteration 103
# loss = 201020.265625
# exp = tensor(5.8287)
# Iteration 104
# loss = 199956.0
# exp = tensor(5.8264)
# Iteration 105
# loss = 198903.734375
# exp = tensor(5.8240)
# Iteration 106
# loss = 197863.125
# exp = tensor(5.8217)
# Iteration 107
# loss = 196834.046875
# exp = tensor(5.8194)
# Iteration 108
# loss = 195816.390625
# exp = tensor(5.8171)
# Iteration 109
# loss = 194809.8125
# exp = tensor(5.8148)
# Iteration 110
# loss = 193814.203125
# exp = tensor(5.8125)
# Iteration 111
# loss = 192829.234375
# exp = tensor(5.8102)
# Iteration 112
# loss = 191854.796875
# exp = tensor(5.8080)
# Iteration 113
# loss = 190890.578125
# exp = tensor(5.8057)
# Iteration 114
# loss = 189936.484375
# exp = tensor(5.8035)
# Iteration 115
# loss = 188992.390625
# exp = tensor(5.8013)
# Iteration 116
# loss = 188058.015625
# exp = tensor(5.7991)
# Iteration 117
# loss = 187133.234375
# exp = tensor(5.7969)
# Iteration 118
# loss = 186218.0
# exp = tensor(5.7947)
# Iteration 119
# loss = 185311.953125
# exp = tensor(5.7925)
# Iteration 120
# loss = 184415.046875
# exp = tensor(5.7903)
# Iteration 121
# loss = 183527.1875
# exp = tensor(5.7882)
# Iteration 122
# loss = 182648.09375
# exp = tensor(5.7861)
# Iteration 123
# loss = 181777.859375
# exp = tensor(5.7839)
# Iteration 124
# loss = 180916.015625
# exp = tensor(5.7818)
# Iteration 125
# loss = 180062.671875
# exp = tensor(5.7797)
# Iteration 126
# loss = 179217.5625
# exp = tensor(5.7776)
# Iteration 127
# loss = 178380.625
# exp = tensor(5.7755)
# Iteration 128
# loss = 177551.734375
# exp = tensor(5.7734)
# Iteration 129
# loss = 176730.859375
# exp = tensor(5.7714)
# Iteration 130
# loss = 175917.71875
# exp = tensor(5.7693)
# Iteration 131
# loss = 175112.4375
# exp = tensor(5.7673)
# Iteration 132
# loss = 174314.546875
# exp = tensor(5.7652)
# Iteration 133
# loss = 173524.203125
# exp = tensor(5.7632)
# Iteration 134
# loss = 172741.296875
# exp = tensor(5.7612)
# Iteration 135
# loss = 171965.59375
# exp = tensor(5.7592)
# Iteration 136
# loss = 171197.015625
# exp = tensor(5.7572)
# Iteration 137
# loss = 170435.53125
# exp = tensor(5.7552)
# Iteration 138
# loss = 169681.03125
# exp = tensor(5.7532)
# Iteration 139
# loss = 168933.3125
# exp = tensor(5.7513)
# Iteration 140
# loss = 168192.296875
# exp = tensor(5.7493)
# Iteration 141
# loss = 167457.921875
# exp = tensor(5.7474)
# Iteration 142
# loss = 166730.140625
# exp = tensor(5.7454)
# Iteration 143
# loss = 166008.875
# exp = tensor(5.7435)
# Iteration 144
# loss = 165294.09375
# exp = tensor(5.7416)
# Iteration 145
# loss = 164585.53125
# exp = tensor(5.7396)
# Iteration 146
# loss = 163883.171875
# exp = tensor(5.7377)
# Iteration 147
# loss = 163186.9375
# exp = tensor(5.7358)
# Iteration 148
# loss = 162496.78125
# exp = tensor(5.7339)
# Iteration 149
# loss = 161812.65625
# exp = tensor(5.7321)
# Iteration 150
# loss = 161134.328125
# exp = tensor(5.7302)
# Iteration 151
# loss = 160461.921875
# exp = tensor(5.7283)
# Iteration 152
# loss = 159795.21875
# exp = tensor(5.7265)
# Iteration 153
# loss = 159134.1875
# exp = tensor(5.7246)
# Iteration 154
# loss = 158478.734375
# exp = tensor(5.7228)
# Iteration 155
# loss = 157828.703125
# exp = tensor(5.7209)
# Iteration 156
# loss = 157184.1875
# exp = tensor(5.7191)
# Iteration 157
# loss = 156544.96875
# exp = tensor(5.7173)
# Iteration 158
# loss = 155911.15625
# exp = tensor(5.7155)
# Iteration 159
# loss = 155282.578125
# exp = tensor(5.7137)
# Iteration 160
# loss = 154659.1875
# exp = tensor(5.7119)
# Iteration 161
# loss = 154040.90625
# exp = tensor(5.7101)
# Iteration 162
# loss = 153427.71875
# exp = tensor(5.7083)
# Iteration 163
# loss = 152819.4375
# exp = tensor(5.7066)
# Iteration 164
# loss = 152216.140625
# exp = tensor(5.7048)
# Iteration 165
# loss = 151617.671875
# exp = tensor(5.7030)
# Iteration 166
# loss = 151023.953125
# exp = tensor(5.7013)
# Iteration 167
# loss = 150434.984375
# exp = tensor(5.6995)
# Iteration 168
# loss = 149850.703125
# exp = tensor(5.6978)
# Iteration 169
# loss = 149271.078125
# exp = tensor(5.6961)
# Iteration 170
# loss = 148696.0625
# exp = tensor(5.6944)
# Iteration 171
# loss = 148125.5
# exp = tensor(5.6926)
# Iteration 172
# loss = 147559.453125
# exp = tensor(5.6909)
# Iteration 173
# loss = 146997.796875
# exp = tensor(5.6892)
# Iteration 174
# loss = 146440.4375
# exp = tensor(5.6875)
# Iteration 175
# loss = 145887.40625
# exp = tensor(5.6858)
# Iteration 176
# loss = 145338.609375
# exp = tensor(5.6842)
# Iteration 177
# loss = 144794.03125
# exp = tensor(5.6825)
# Iteration 178
# loss = 144253.65625
# exp = tensor(5.6808)
# Iteration 179
# loss = 143717.453125
# exp = tensor(5.6792)
# Iteration 180
# loss = 143185.21875
# exp = tensor(5.6775)
# Iteration 181
# loss = 142657.078125
# exp = tensor(5.6759)
# Iteration 182
# loss = 142132.875
# exp = tensor(5.6742)
# Iteration 183
# loss = 141612.546875
# exp = tensor(5.6726)
# Iteration 184
# loss = 141096.234375
# exp = tensor(5.6709)
# Iteration 185
# loss = 140583.765625
# exp = tensor(5.6693)
# Iteration 186
# loss = 140074.9375
# exp = tensor(5.6677)
# Iteration 187
# loss = 139569.890625
# exp = tensor(5.6661)
# Iteration 188
# loss = 139068.59375
# exp = tensor(5.6645)
# Iteration 189
# loss = 138571.015625
# exp = tensor(5.6629)
# Iteration 190
# loss = 138076.984375
# exp = tensor(5.6613)
# Iteration 191
# loss = 137586.625
# exp = tensor(5.6597)
# Iteration 192
# loss = 137099.765625
# exp = tensor(5.6581)
# Iteration 193
# loss = 136616.359375
# exp = tensor(5.6565)
# Iteration 194
# loss = 136136.421875
# exp = tensor(5.6550)
# Iteration 195
# loss = 135660.03125
# exp = tensor(5.6534)
# Iteration 196
# loss = 135186.90625
# exp = tensor(5.6518)
# Iteration 197
# loss = 134717.15625
# exp = tensor(5.6503)
# Iteration 198
# loss = 134250.75
# exp = tensor(5.6487)
# Iteration 199
# loss = 133787.671875
# exp = tensor(5.6472)
# Iteration 200
# loss = 133327.90625
# exp = tensor(5.6457)
# Iteration 201
# loss = 132871.265625
# exp = tensor(5.6441)
# Iteration 202
# loss = 132417.890625
# exp = tensor(5.6426)
# Iteration 203
# loss = 131967.609375
# exp = tensor(5.6411)
# Iteration 204
# loss = 131520.40625
# exp = tensor(5.6396)
# Iteration 205
# loss = 131076.25
# exp = tensor(5.6381)
# Iteration 206
# loss = 130635.2578125
# exp = tensor(5.6366)
# Iteration 207
# loss = 130197.2890625
# exp = tensor(5.6351)
# Iteration 208
# loss = 129762.3046875
# exp = tensor(5.6336)
# Iteration 209
# loss = 129330.296875
# exp = tensor(5.6321)
# Iteration 210
# loss = 128901.1015625
# exp = tensor(5.6306)
# Iteration 211
# loss = 128474.828125
# exp = tensor(5.6291)
# Iteration 212
# loss = 128051.4765625
# exp = tensor(5.6276)
# Iteration 213
# loss = 127630.875
# exp = tensor(5.6262)
# Iteration 214
# loss = 127213.1484375
# exp = tensor(5.6247)
# Iteration 215
# loss = 126798.1484375
# exp = tensor(5.6232)
# Iteration 216
# loss = 126385.96875
# exp = tensor(5.6218)
# Iteration 217
# loss = 125976.4921875
# exp = tensor(5.6203)
# Iteration 218
# loss = 125569.6640625
# exp = tensor(5.6189)
# Iteration 219
# loss = 125165.4921875
# exp = tensor(5.6175)
# Iteration 220
# loss = 124764.078125
# exp = tensor(5.6160)
# Iteration 221
# loss = 124365.2890625
# exp = tensor(5.6146)
# Iteration 222
# loss = 123969.0859375
# exp = tensor(5.6132)
# Iteration 223
# loss = 123575.34375
# exp = tensor(5.6117)
# Iteration 224
# loss = 123184.140625
# exp = tensor(5.6103)
# Iteration 225
# loss = 122795.5078125
# exp = tensor(5.6089)
# Iteration 226
# loss = 122409.40625
# exp = tensor(5.6075)
# Iteration 227
# loss = 122025.6796875
# exp = tensor(5.6061)
# Iteration 228
# loss = 121644.453125
# exp = tensor(5.6047)
# Iteration 229
# loss = 121265.5859375
# exp = tensor(5.6033)
# Iteration 230
# loss = 120889.1875
# exp = tensor(5.6019)
# Iteration 231
# loss = 120515.109375
# exp = tensor(5.6005)
# Iteration 232
# loss = 120143.4765625
# exp = tensor(5.5992)
# Iteration 233
# loss = 119774.1328125
# exp = tensor(5.5978)
# Iteration 234
# loss = 119407.078125
# exp = tensor(5.5964)
# Iteration 235
# loss = 119042.28125
# exp = tensor(5.5950)
# Iteration 236
# loss = 118679.7421875
# exp = tensor(5.5937)
# Iteration 237
# loss = 118319.4375
# exp = tensor(5.5923)
# Iteration 238
# loss = 117961.3671875
# exp = tensor(5.5910)
# Iteration 239
# loss = 117605.5
# exp = tensor(5.5896)
# Iteration 240
# loss = 117251.84375
# exp = tensor(5.5883)
# Iteration 241
# loss = 116900.359375
# exp = tensor(5.5869)
# Iteration 242
# loss = 116551.0546875
# exp = tensor(5.5856)
# Iteration 243
# loss = 116203.78125
# exp = tensor(5.5843)
# Iteration 244
# loss = 115858.65625
# exp = tensor(5.5829)
# Iteration 245
# loss = 115515.546875
# exp = tensor(5.5816)
# Iteration 246
# loss = 115174.546875
# exp = tensor(5.5803)
# Iteration 247
# loss = 114835.5390625
# exp = tensor(5.5790)
# Iteration 248
# loss = 114498.6328125
# exp = tensor(5.5777)
# Iteration 249
# loss = 114163.6796875
# exp = tensor(5.5763)
# Iteration 250
# loss = 113830.8046875
# exp = tensor(5.5750)
# Iteration 251
# loss = 113499.8671875
# exp = tensor(5.5737)
# Iteration 252
# loss = 113170.8515625
# exp = tensor(5.5724)
# Iteration 253
# loss = 112843.7578125
# exp = tensor(5.5711)
# Iteration 254
# loss = 112518.5703125
# exp = tensor(5.5699)
# Iteration 255
# loss = 112195.265625
# exp = tensor(5.5686)
# Iteration 256
# loss = 111873.859375
# exp = tensor(5.5673)
# Iteration 257
# loss = 111554.3125
# exp = tensor(5.5660)
# Iteration 258
# loss = 111236.6328125
# exp = tensor(5.5647)
# Iteration 259
# loss = 110920.8046875
# exp = tensor(5.5635)
# Iteration 260
# loss = 110606.8203125
# exp = tensor(5.5622)
# Iteration 261
# loss = 110294.65625
# exp = tensor(5.5609)
# Iteration 262
# loss = 109984.3125
# exp = tensor(5.5597)
# Iteration 263
# loss = 109675.6640625
# exp = tensor(5.5584)
# Iteration 264
# loss = 109368.8125
# exp = tensor(5.5572)
# Iteration 265
# loss = 109063.625
# exp = tensor(5.5559)
# Iteration 266
# loss = 108760.2265625
# exp = tensor(5.5547)
# Iteration 267
# loss = 108458.6015625
# exp = tensor(5.5534)
# Iteration 268
# loss = 108158.609375
# exp = tensor(5.5522)
# Iteration 269
# loss = 107860.2578125
# exp = tensor(5.5510)
# Iteration 270
# loss = 107563.640625
# exp = tensor(5.5497)
# Iteration 271
# loss = 107268.65625
# exp = tensor(5.5485)
# Iteration 272
# loss = 106975.265625
# exp = tensor(5.5473)
# Iteration 273
# loss = 106683.5859375
# exp = tensor(5.5461)
# Iteration 274
# loss = 106393.5
# exp = tensor(5.5448)
# Iteration 275
# loss = 106104.9921875
# exp = tensor(5.5436)
# Iteration 276
# loss = 105818.0625
# exp = tensor(5.5424)
# Iteration 277
# loss = 105532.6875
# exp = tensor(5.5412)
# Iteration 278
# loss = 105248.8671875
# exp = tensor(5.5400)
# Iteration 279
# loss = 104966.6015625
# exp = tensor(5.5388)
# Iteration 280
# loss = 104685.859375
# exp = tensor(5.5376)
# Iteration 281
# loss = 104406.65625
# exp = tensor(5.5364)
# Iteration 282
# loss = 104128.9765625
# exp = tensor(5.5352)
# Iteration 283
# loss = 103852.8125
# exp = tensor(5.5340)
# Iteration 284
# loss = 103578.15625
# exp = tensor(5.5328)
# Iteration 285
# loss = 103304.984375
# exp = tensor(5.5317)
# Iteration 286
# loss = 103033.1953125
# exp = tensor(5.5305)
# Iteration 287
# loss = 102762.890625
# exp = tensor(5.5293)
# Iteration 288
# loss = 102494.0625
# exp = tensor(5.5281)
# Iteration 289
# loss = 102226.5859375
# exp = tensor(5.5270)
# Iteration 290
# loss = 101960.5703125
# exp = tensor(5.5258)
# Iteration 291
# loss = 101695.8984375
# exp = tensor(5.5246)
# Iteration 292
# loss = 101432.671875
# exp = tensor(5.5235)
# Iteration 293
# loss = 101170.7734375
# exp = tensor(5.5223)
# Iteration 294
# loss = 100910.3046875
# exp = tensor(5.5212)
# Iteration 295
# loss = 100651.1484375
# exp = tensor(5.5200)
# Iteration 296
# loss = 100393.3984375
# exp = tensor(5.5189)
# Iteration 297
# loss = 100136.9609375
# exp = tensor(5.5177)
# Iteration 298
# loss = 99881.8125
# exp = tensor(5.5166)
# Iteration 299
# loss = 99628.0546875
# exp = tensor(5.5155)
# Iteration 300
# loss = 99375.578125
# exp = tensor(5.5143)
# Iteration 301
# loss = 99124.3828125
# exp = tensor(5.5132)
# Iteration 302
# loss = 98874.4453125
# exp = tensor(5.5121)
# Iteration 303
# loss = 98625.7734375
# exp = tensor(5.5109)
# Iteration 304
# loss = 98378.453125
# exp = tensor(5.5098)
# Iteration 305
# loss = 98132.3828125
# exp = tensor(5.5087)
# Iteration 306
# loss = 97887.5703125
# exp = tensor(5.5076)
# Iteration 307
# loss = 97643.9765625
# exp = tensor(5.5065)
# Iteration 308
# loss = 97401.6171875
# exp = tensor(5.5054)
# Iteration 309
# loss = 97160.4765625
# exp = tensor(5.5042)
# Iteration 310
# loss = 96920.5546875
# exp = tensor(5.5031)
# Iteration 311
# loss = 96681.84375
# exp = tensor(5.5020)
# Iteration 312
# loss = 96444.2421875
# exp = tensor(5.5009)
# Iteration 313
# loss = 96207.8359375
# exp = tensor(5.4998)
# Iteration 314
# loss = 95972.6171875
# exp = tensor(5.4987)
# Iteration 315
# loss = 95738.5859375
# exp = tensor(5.4977)
# Iteration 316
# loss = 95505.734375
# exp = tensor(5.4966)
# Iteration 317
# loss = 95273.9609375
# exp = tensor(5.4955)
# Iteration 318
# loss = 95043.359375
# exp = tensor(5.4944)
# Iteration 319
# loss = 94813.9140625
# exp = tensor(5.4933)
# Iteration 320
# loss = 94585.5390625
# exp = tensor(5.4922)
# Iteration 321
# loss = 94358.3125
# exp = tensor(5.4912)
# Iteration 322
# loss = 94132.125
# exp = tensor(5.4901)
# Iteration 323
# loss = 93907.09375
# exp = tensor(5.4890)
# Iteration 324
# loss = 93683.1875
# exp = tensor(5.4879)
# Iteration 325
# loss = 93460.3125
# exp = tensor(5.4869)
# Iteration 326
# loss = 93238.4765625
# exp = tensor(5.4858)
# Iteration 327
# loss = 93017.7578125
# exp = tensor(5.4848)
# Iteration 328
# loss = 92798.0546875
# exp = tensor(5.4837)
# Iteration 329
# loss = 92579.4609375
# exp = tensor(5.4826)
# Iteration 330
# loss = 92361.875
# exp = tensor(5.4816)
# Iteration 331
# loss = 92145.296875
# exp = tensor(5.4805)
# Iteration 332
# loss = 91929.8046875
# exp = tensor(5.4795)
# Iteration 333
# loss = 91715.3046875
# exp = tensor(5.4784)
# Iteration 334
# loss = 91501.796875
# exp = tensor(5.4774)
# Iteration 335
# loss = 91289.2734375
# exp = tensor(5.4764)
# Iteration 336
# loss = 91077.828125
# exp = tensor(5.4753)
# Iteration 337
# loss = 90867.3515625
# exp = tensor(5.4743)
# Iteration 338
# loss = 90657.8515625
# exp = tensor(5.4733)
# Iteration 339
# loss = 90449.3046875
# exp = tensor(5.4722)
# Iteration 340
# loss = 90241.7265625
# exp = tensor(5.4712)
# Iteration 341
# loss = 90035.1015625
# exp = tensor(5.4702)
# Iteration 342
# loss = 89829.4296875
# exp = tensor(5.4691)
# Iteration 343
# loss = 89624.7109375
# exp = tensor(5.4681)
# Iteration 344
# loss = 89420.921875
# exp = tensor(5.4671)
# Iteration 345
# loss = 89218.078125
# exp = tensor(5.4661)
# Iteration 346
# loss = 89016.171875
# exp = tensor(5.4651)
# Iteration 347
# loss = 88815.1953125
# exp = tensor(5.4641)
# Iteration 348
# loss = 88615.140625
# exp = tensor(5.4631)
# Iteration 349
# loss = 88416.015625
# exp = tensor(5.4621)
# Iteration 350
# loss = 88217.796875
# exp = tensor(5.4610)
# Iteration 351
# loss = 88020.5
# exp = tensor(5.4600)
# Iteration 352
# loss = 87824.1015625
# exp = tensor(5.4590)
# Iteration 353
# loss = 87628.6171875
# exp = tensor(5.4580)
# Iteration 354
# loss = 87433.9375
# exp = tensor(5.4571)
# Iteration 355
# loss = 87240.1640625
# exp = tensor(5.4561)
# Iteration 356
# loss = 87047.2734375
# exp = tensor(5.4551)
# Iteration 357
# loss = 86855.265625
# exp = tensor(5.4541)
# Iteration 358
# loss = 86664.0703125
# exp = tensor(5.4531)
# Iteration 359
# loss = 86473.75
# exp = tensor(5.4521)
# Iteration 360
# loss = 86284.296875
# exp = tensor(5.4511)
# Iteration 361
# loss = 86095.6328125
# exp = tensor(5.4502)
# Iteration 362
# loss = 85907.8359375
# exp = tensor(5.4492)
# Iteration 363
# loss = 85720.8125
# exp = tensor(5.4482)
# Iteration 364
# loss = 85534.6640625
# exp = tensor(5.4472)
# Iteration 365
# loss = 85349.2734375
# exp = tensor(5.4463)
# Iteration 366
# loss = 85164.734375
# exp = tensor(5.4453)
# Iteration 367
# loss = 84981.0546875
# exp = tensor(5.4443)
# Iteration 368
# loss = 84798.125
# exp = tensor(5.4434)
# Iteration 369
# loss = 84615.9609375
# exp = tensor(5.4424)
# Iteration 370
# loss = 84434.6328125
# exp = tensor(5.4414)
# Iteration 371
# loss = 84254.0546875
# exp = tensor(5.4405)
# Iteration 372
# loss = 84074.3046875
# exp = tensor(5.4395)
# Iteration 373
# loss = 83895.296875
# exp = tensor(5.4386)
# Iteration 374
# loss = 83717.03125
# exp = tensor(5.4376)
# Iteration 375
# loss = 83539.5859375
# exp = tensor(5.4367)
# Iteration 376
# loss = 83362.875
# exp = tensor(5.4357)
# Iteration 377
# loss = 83186.890625
# exp = tensor(5.4348)
# Iteration 378
# loss = 83011.7109375
# exp = tensor(5.4338)
# Iteration 379
# loss = 82837.265625
# exp = tensor(5.4329)
# Iteration 380
# loss = 82663.5390625
# exp = tensor(5.4319)
# Iteration 381
# loss = 82490.609375
# exp = tensor(5.4310)
# Iteration 382
# loss = 82318.3984375
# exp = tensor(5.4301)
# Iteration 383
# loss = 82146.8828125
# exp = tensor(5.4291)
# Iteration 384
# loss = 81976.09375
# exp = tensor(5.4282)
# Iteration 385
# loss = 81806.0
# exp = tensor(5.4273)
# Iteration 386
# loss = 81636.6015625
# exp = tensor(5.4263)
# Iteration 387
# loss = 81468.0
# exp = tensor(5.4254)
# Iteration 388
# loss = 81300.078125
# exp = tensor(5.4245)
# Iteration 389
# loss = 81132.859375
# exp = tensor(5.4236)
# Iteration 390
# loss = 80966.328125
# exp = tensor(5.4227)
# Iteration 391
# loss = 80800.484375
# exp = tensor(5.4217)
# Iteration 392
# loss = 80635.3125
# exp = tensor(5.4208)
# Iteration 393
# loss = 80470.8359375
# exp = tensor(5.4199)
# Iteration 394
# loss = 80307.03125
# exp = tensor(5.4190)
# Iteration 395
# loss = 80143.8984375
# exp = tensor(5.4181)
# Iteration 396
# loss = 79981.4375
# exp = tensor(5.4172)
# Iteration 397
# loss = 79819.6484375
# exp = tensor(5.4163)
# Iteration 398
# loss = 79658.5234375
# exp = tensor(5.4154)
# Iteration 399
# loss = 79498.0625
# exp = tensor(5.4145)
# Iteration 400
# loss = 79338.2734375
# exp = tensor(5.4136)
# Iteration 401
# loss = 79179.125
# exp = tensor(5.4127)
# Iteration 402
# loss = 79020.5625
# exp = tensor(5.4118)
# Iteration 403
# loss = 78862.6484375
# exp = tensor(5.4109)
# Iteration 404
# loss = 78705.390625
# exp = tensor(5.4100)
# Iteration 405
# loss = 78548.7734375
# exp = tensor(5.4091)
# Iteration 406
# loss = 78392.8046875
# exp = tensor(5.4082)
# Iteration 407
# loss = 78237.484375
# exp = tensor(5.4073)
# Iteration 408
# loss = 78082.7109375
# exp = tensor(5.4064)
# Iteration 409
# loss = 77928.5859375
# exp = tensor(5.4055)
# Iteration 410
# loss = 77775.09375
# exp = tensor(5.4047)
# Iteration 411
# loss = 77622.2265625
# exp = tensor(5.4038)
# Iteration 412
# loss = 77469.9140625
# exp = tensor(5.4029)
# Iteration 413
# loss = 77318.2265625
# exp = tensor(5.4020)
# Iteration 414
# loss = 77167.171875
# exp = tensor(5.4011)
# Iteration 415
# loss = 77016.6484375
# exp = tensor(5.4003)
# Iteration 416
# loss = 76866.7578125
# exp = tensor(5.3994)
# Iteration 417
# loss = 76717.4765625
# exp = tensor(5.3985)
# Iteration 418
# loss = 76568.734375
# exp = tensor(5.3977)
# Iteration 419
# loss = 76420.6015625
# exp = tensor(5.3968)
# Iteration 420
# loss = 76273.0859375
# exp = tensor(5.3959)
# Iteration 421
# loss = 76126.09375
# exp = tensor(5.3951)
# Iteration 422
# loss = 75979.7109375
# exp = tensor(5.3942)
# Iteration 423
# loss = 75833.8515625
# exp = tensor(5.3933)
# Iteration 424
# loss = 75688.59375
# exp = tensor(5.3925)
# Iteration 425
# loss = 75543.859375
# exp = tensor(5.3916)
# Iteration 426
# loss = 75399.71875
# exp = tensor(5.3908)
# Iteration 427
# loss = 75256.09375
# exp = tensor(5.3899)
# Iteration 428
# loss = 75113.0625
# exp = tensor(5.3891)
# Iteration 429
# loss = 74970.546875
# exp = tensor(5.3882)
# Iteration 430
# loss = 74828.6171875
# exp = tensor(5.3874)
# Iteration 431
# loss = 74687.1953125
# exp = tensor(5.3865)
# Iteration 432
# loss = 74546.359375
# exp = tensor(5.3857)
# Iteration 433
# loss = 74406.0234375
# exp = tensor(5.3848)
# Iteration 434
# loss = 74266.1875
# exp = tensor(5.3840)
# Iteration 435
# loss = 74126.9296875
# exp = tensor(5.3831)
# Iteration 436
# loss = 73988.1796875
# exp = tensor(5.3823)
# Iteration 437
# loss = 73850.0
# exp = tensor(5.3815)
# Iteration 438
# loss = 73712.3046875
# exp = tensor(5.3806)
# Iteration 439
# loss = 73575.109375
# exp = tensor(5.3798)
# Iteration 440
# loss = 73438.484375
# exp = tensor(5.3790)
# Iteration 441
# loss = 73302.34375
# exp = tensor(5.3781)
# Iteration 442
# loss = 73166.6875
# exp = tensor(5.3773)
# Iteration 443
# loss = 73031.59375
# exp = tensor(5.3765)
# Iteration 444
# loss = 72896.984375
# exp = tensor(5.3756)
# Iteration 445
# loss = 72762.8515625
# exp = tensor(5.3748)
# Iteration 446
# loss = 72629.203125
# exp = tensor(5.3740)
# Iteration 447
# loss = 72496.109375
# exp = tensor(5.3732)
# Iteration 448
# loss = 72363.484375
# exp = tensor(5.3724)
# Iteration 449
# loss = 72231.3359375
# exp = tensor(5.3715)
# Iteration 450
# loss = 72099.6640625
# exp = tensor(5.3707)
# Iteration 451
# loss = 71968.453125
# exp = tensor(5.3699)
# Iteration 452
# loss = 71837.796875
# exp = tensor(5.3691)
# Iteration 453
# loss = 71707.6015625
# exp = tensor(5.3683)
# Iteration 454
# loss = 71577.8671875
# exp = tensor(5.3675)
# Iteration 455
# loss = 71448.6015625
# exp = tensor(5.3667)
# Iteration 456
# loss = 71319.796875
# exp = tensor(5.3659)
# Iteration 457
# loss = 71191.453125
# exp = tensor(5.3650)
# Iteration 458
# loss = 71063.5625
# exp = tensor(5.3642)
# Iteration 459
# loss = 70936.203125
# exp = tensor(5.3634)
# Iteration 460
# loss = 70809.3046875
# exp = tensor(5.3626)
# Iteration 461
# loss = 70682.859375
# exp = tensor(5.3618)
# Iteration 462
# loss = 70556.859375
# exp = tensor(5.3610)
# Iteration 463
# loss = 70431.3125
# exp = tensor(5.3602)
# Iteration 464
# loss = 70306.203125
# exp = tensor(5.3594)
# Iteration 465
# loss = 70181.5546875
# exp = tensor(5.3586)
# Iteration 466
# loss = 70057.34375
# exp = tensor(5.3579)
# Iteration 467
# loss = 69933.5859375
# exp = tensor(5.3571)
# Iteration 468
# loss = 69810.2578125
# exp = tensor(5.3563)
# Iteration 469
# loss = 69687.3671875
# exp = tensor(5.3555)
# Iteration 470
# loss = 69564.9296875
# exp = tensor(5.3547)
# Iteration 471
# loss = 69442.9140625
# exp = tensor(5.3539)
# Iteration 472
# loss = 69321.34375
# exp = tensor(5.3531)
# Iteration 473
# loss = 69200.203125
# exp = tensor(5.3523)
# Iteration 474
# loss = 69079.4921875
# exp = tensor(5.3516)
# Iteration 475
# loss = 68959.2265625
# exp = tensor(5.3508)
# Iteration 476
# loss = 68839.3046875
# exp = tensor(5.3500)
# Iteration 477
# loss = 68719.8125
# exp = tensor(5.3492)
# Iteration 478
# loss = 68600.7421875
# exp = tensor(5.3484)
# Iteration 479
# loss = 68482.1015625
# exp = tensor(5.3477)
# Iteration 480
# loss = 68363.8828125
# exp = tensor(5.3469)
# Iteration 481
# loss = 68246.09375
# exp = tensor(5.3461)
# Iteration 482
# loss = 68128.71875
# exp = tensor(5.3453)
# Iteration 483
# loss = 68011.765625
# exp = tensor(5.3446)
# Iteration 484
# loss = 67895.15625
# exp = tensor(5.3438)
# Iteration 485
# loss = 67778.9609375
# exp = tensor(5.3430)
# Iteration 486
# loss = 67663.1875
# exp = tensor(5.3423)
# Iteration 487
# loss = 67547.8203125
# exp = tensor(5.3415)
# Iteration 488
# loss = 67432.8671875
# exp = tensor(5.3407)
# Iteration 489
# loss = 67318.2578125
# exp = tensor(5.3400)
# Iteration 490
# loss = 67204.0546875
# exp = tensor(5.3392)
# Iteration 491
# loss = 67090.25
# exp = tensor(5.3385)
# Iteration 492
# loss = 66976.8671875
# exp = tensor(5.3377)
# Iteration 493
# loss = 66863.8125
# exp = tensor(5.3370)
# Iteration 494
# loss = 66751.1640625
# exp = tensor(5.3362)
# Iteration 495
# loss = 66638.9140625
# exp = tensor(5.3354)
# Iteration 496
# loss = 66527.0625
# exp = tensor(5.3347)
# Iteration 497
# loss = 66415.546875
# exp = tensor(5.3339)
# Iteration 498
# loss = 66304.4296875
# exp = tensor(5.3332)
# Iteration 499
# loss = 66193.7109375
# exp = tensor(5.3324)
# Iteration 500
# loss = 66083.3125
# exp = tensor(5.3317)
# Iteration 501
# loss = 65973.3046875
# exp = tensor(5.3309)
# Iteration 502
# loss = 65863.703125
# exp = tensor(5.3302)
# Iteration 503
# loss = 65754.4140625
# exp = tensor(5.3295)
# Iteration 504
# loss = 65645.5234375
# exp = tensor(5.3287)
# Iteration 505
# loss = 65537.015625
# exp = tensor(5.3280)
# Iteration 506
# loss = 65428.828125
# exp = tensor(5.3272)
# Iteration 507
# loss = 65321.03125
# exp = tensor(5.3265)
# Iteration 508
# loss = 65213.546875
# exp = tensor(5.3258)
# Iteration 509
# loss = 65106.44921875
# exp = tensor(5.3250)
# Iteration 510
# loss = 64999.734375
# exp = tensor(5.3243)
# Iteration 511
# loss = 64893.3359375
# exp = tensor(5.3236)
# Iteration 512
# loss = 64787.3125
# exp = tensor(5.3228)
# Iteration 513
# loss = 64681.60546875
# exp = tensor(5.3221)
# Iteration 514
# loss = 64576.27734375
# exp = tensor(5.3214)
# Iteration 515
# loss = 64471.25390625
# exp = tensor(5.3206)
# Iteration 516
# loss = 64366.609375
# exp = tensor(5.3199)
# Iteration 517
# loss = 64262.26953125
# exp = tensor(5.3192)
# Iteration 518
# loss = 64158.3046875
# exp = tensor(5.3184)
# Iteration 519
# loss = 64054.6484375
# exp = tensor(5.3177)
# Iteration 520
# loss = 63951.359375
# exp = tensor(5.3170)
# Iteration 521
# loss = 63848.37109375
# exp = tensor(5.3163)
# Iteration 522
# loss = 63745.7578125
# exp = tensor(5.3156)
# Iteration 523
# loss = 63643.44140625
# exp = tensor(5.3148)
# Iteration 524
# loss = 63541.4921875
# exp = tensor(5.3141)
# Iteration 525
# loss = 63439.83984375
# exp = tensor(5.3134)
# Iteration 526
# loss = 63338.5546875
# exp = tensor(5.3127)
# Iteration 527
# loss = 63237.56640625
# exp = tensor(5.3120)
# Iteration 528
# loss = 63136.94140625
# exp = tensor(5.3113)
# Iteration 529
# loss = 63036.609375
# exp = tensor(5.3105)
# Iteration 530
# loss = 62936.640625
# exp = tensor(5.3098)
# Iteration 531
# loss = 62836.9609375
# exp = tensor(5.3091)
# Iteration 532
# loss = 62737.57421875
# exp = tensor(5.3084)
# Iteration 533
# loss = 62638.546875
# exp = tensor(5.3077)
# Iteration 534
# loss = 62539.80078125
# exp = tensor(5.3070)
# Iteration 535
# loss = 62441.4140625
# exp = tensor(5.3063)
# Iteration 536
# loss = 62343.31640625
# exp = tensor(5.3056)
# Iteration 537
# loss = 62245.50390625
# exp = tensor(5.3049)
# Iteration 538
# loss = 62148.04296875
# exp = tensor(5.3042)
# Iteration 539
# loss = 62050.87109375
# exp = tensor(5.3035)
# Iteration 540
# loss = 61953.98046875
# exp = tensor(5.3028)
# Iteration 541
# loss = 61857.44140625
# exp = tensor(5.3021)
# Iteration 542
# loss = 61761.1796875
# exp = tensor(5.3014)
# Iteration 543
# loss = 61665.19921875
# exp = tensor(5.3007)
# Iteration 544
# loss = 61569.5703125
# exp = tensor(5.3000)
# Iteration 545
# loss = 61474.21484375
# exp = tensor(5.2993)
# Iteration 546
# loss = 61379.140625
# exp = tensor(5.2986)
# Iteration 547
# loss = 61284.40234375
# exp = tensor(5.2979)
# Iteration 548
# loss = 61189.9453125
# exp = tensor(5.2972)
# Iteration 549
# loss = 61095.765625
# exp = tensor(5.2965)
# Iteration 550
# loss = 61001.86328125
# exp = tensor(5.2958)
# Iteration 551
# loss = 60908.296875
# exp = tensor(5.2952)
# Iteration 552
# loss = 60814.99609375
# exp = tensor(5.2945)
# Iteration 553
# loss = 60721.9765625
# exp = tensor(5.2938)
# Iteration 554
# loss = 60629.2265625
# exp = tensor(5.2931)
# Iteration 555
# loss = 60536.8125
# exp = tensor(5.2924)
# Iteration 556
# loss = 60444.6640625
# exp = tensor(5.2917)
# Iteration 557
# loss = 60352.7890625
# exp = tensor(5.2910)
# Iteration 558
# loss = 60261.17578125
# exp = tensor(5.2904)
# Iteration 559
# loss = 60169.8359375
# exp = tensor(5.2897)
# Iteration 560
# loss = 60078.82421875
# exp = tensor(5.2890)
# Iteration 561
# loss = 59988.078125
# exp = tensor(5.2883)
# Iteration 562
# loss = 59897.59765625
# exp = tensor(5.2877)
# Iteration 563
# loss = 59807.37890625
# exp = tensor(5.2870)
# Iteration 564
# loss = 59717.42578125
# exp = tensor(5.2863)
# Iteration 565
# loss = 59627.79296875
# exp = tensor(5.2856)
# Iteration 566
# loss = 59538.42578125
# exp = tensor(5.2850)
# Iteration 567
# loss = 59449.3203125
# exp = tensor(5.2843)
# Iteration 568
# loss = 59360.47265625
# exp = tensor(5.2836)
# Iteration 569
# loss = 59271.8828125
# exp = tensor(5.2829)
# Iteration 570
# loss = 59183.5546875
# exp = tensor(5.2823)
# Iteration 571
# loss = 59095.4765625
# exp = tensor(5.2816)
# Iteration 572
# loss = 59007.73046875
# exp = tensor(5.2809)
# Iteration 573
# loss = 58920.23046875
# exp = tensor(5.2803)
# Iteration 574
# loss = 58832.984375
# exp = tensor(5.2796)
# Iteration 575
# loss = 58745.99609375
# exp = tensor(5.2789)
# Iteration 576
# loss = 58659.26171875
# exp = tensor(5.2783)
# Iteration 577
# loss = 58572.77734375
# exp = tensor(5.2776)
# Iteration 578
# loss = 58486.546875
# exp = tensor(5.2770)
# Iteration 579
# loss = 58400.5703125
# exp = tensor(5.2763)
# Iteration 580
# loss = 58314.83984375
# exp = tensor(5.2756)
# Iteration 581
# loss = 58229.36328125
# exp = tensor(5.2750)
# Iteration 582
# loss = 58144.1328125
# exp = tensor(5.2743)
# Iteration 583
# loss = 58059.15234375
# exp = tensor(5.2737)
# Iteration 584
# loss = 57974.421875
# exp = tensor(5.2730)
# Iteration 585
# loss = 57889.99609375
# exp = tensor(5.2724)
# Iteration 586
# loss = 57805.8203125
# exp = tensor(5.2717)
# Iteration 587
# loss = 57721.8828125
# exp = tensor(5.2711)
# Iteration 588
# loss = 57638.1953125
# exp = tensor(5.2704)
# Iteration 589
# loss = 57554.74609375
# exp = tensor(5.2698)
# Iteration 590
# loss = 57471.546875
# exp = tensor(5.2691)
# Iteration 591
# loss = 57388.58203125
# exp = tensor(5.2685)
# Iteration 592
# loss = 57305.8671875
# exp = tensor(5.2678)
# Iteration 593
# loss = 57223.390625
# exp = tensor(5.2672)
# Iteration 594
# loss = 57141.15234375
# exp = tensor(5.2665)
# Iteration 595
# loss = 57059.16015625
# exp = tensor(5.2659)
# Iteration 596
# loss = 56977.3984375
# exp = tensor(5.2652)
# Iteration 597
# loss = 56895.875
# exp = tensor(5.2646)
# Iteration 598
# loss = 56814.53515625
# exp = tensor(5.2640)
# Iteration 599
# loss = 56733.43359375
# exp = tensor(5.2633)
# Iteration 600
# loss = 56652.5625
# exp = tensor(5.2627)
# Iteration 601
# loss = 56571.92578125
# exp = tensor(5.2620)
# Iteration 602
# loss = 56491.53125
# exp = tensor(5.2614)
# Iteration 603
# loss = 56411.3671875
# exp = tensor(5.2608)
# Iteration 604
# loss = 56331.43359375
# exp = tensor(5.2601)
# Iteration 605
# loss = 56251.734375
# exp = tensor(5.2595)
# Iteration 606
# loss = 56172.2734375
# exp = tensor(5.2589)
# Iteration 607
# loss = 56093.04296875
# exp = tensor(5.2582)
# Iteration 608
# loss = 56014.03515625
# exp = tensor(5.2576)
# Iteration 609
# loss = 55935.26953125
# exp = tensor(5.2570)
# Iteration 610
# loss = 55856.72265625
# exp = tensor(5.2563)
# Iteration 611
# loss = 55778.3515625
# exp = tensor(5.2557)
# Iteration 612
# loss = 55700.20703125
# exp = tensor(5.2551)
# Iteration 613
# loss = 55622.2890625
# exp = tensor(5.2545)
# Iteration 614
# loss = 55544.6015625
# exp = tensor(5.2538)
# Iteration 615
# loss = 55467.13671875
# exp = tensor(5.2532)
# Iteration 616
# loss = 55389.90234375
# exp = tensor(5.2526)
# Iteration 617
# loss = 55312.890625
# exp = tensor(5.2520)
# Iteration 618
# loss = 55236.10546875
# exp = tensor(5.2513)
# Iteration 619
# loss = 55159.48046875
# exp = tensor(5.2507)
# Iteration 620
# loss = 55083.0859375
# exp = tensor(5.2501)
# Iteration 621
# loss = 55006.9140625
# exp = tensor(5.2495)
# Iteration 622
# loss = 54930.95703125
# exp = tensor(5.2488)
# Iteration 623
# loss = 54855.2265625
# exp = tensor(5.2482)
# Iteration 624
# loss = 54779.65625
# exp = tensor(5.2476)
# Iteration 625
# loss = 54704.3125
# exp = tensor(5.2470)
# Iteration 626
# loss = 54629.1796875
# exp = tensor(5.2464)
# Iteration 627
# loss = 54554.26953125
# exp = tensor(5.2458)
# Iteration 628
# loss = 54479.5859375
# exp = tensor(5.2451)
# Iteration 629
# loss = 54405.11328125
# exp = tensor(5.2445)
# Iteration 630
# loss = 54330.8046875
# exp = tensor(5.2439)
# Iteration 631
# loss = 54256.70703125
# exp = tensor(5.2433)
# Iteration 632
# loss = 54182.828125
# exp = tensor(5.2427)
# Iteration 633
# loss = 54109.1640625
# exp = tensor(5.2421)
# Iteration 634
# loss = 54035.66015625
# exp = tensor(5.2415)
# Iteration 635
# loss = 53962.37109375
# exp = tensor(5.2409)
# Iteration 636
# loss = 53889.29296875
# exp = tensor(5.2403)
# Iteration 637
# loss = 53816.4296875
# exp = tensor(5.2397)
# Iteration 638
# loss = 53743.72265625
# exp = tensor(5.2391)
# Iteration 639
# loss = 53671.23046875
# exp = tensor(5.2384)
# Iteration 640
# loss = 53598.9453125
# exp = tensor(5.2378)
# Iteration 641
# loss = 53526.875
# exp = tensor(5.2372)
# Iteration 642
# loss = 53454.95703125
# exp = tensor(5.2366)
# Iteration 643
# loss = 53383.25
# exp = tensor(5.2360)
# Iteration 644
# loss = 53311.75
# exp = tensor(5.2354)
# Iteration 645
# loss = 53240.45703125
# exp = tensor(5.2348)
# Iteration 646
# loss = 53169.32421875
# exp = tensor(5.2342)
# Iteration 647
# loss = 53098.39453125
# exp = tensor(5.2336)
# Iteration 648
# loss = 53027.671875
# exp = tensor(5.2330)
# Iteration 649
# loss = 52957.10546875
# exp = tensor(5.2324)
# Iteration 650
# loss = 52886.7421875
# exp = tensor(5.2318)
# Iteration 651
# loss = 52816.58203125
# exp = tensor(5.2312)
# Iteration 652
# loss = 52746.5703125
# exp = tensor(5.2307)
# Iteration 653
# loss = 52676.76953125
# exp = tensor(5.2301)
# Iteration 654
# loss = 52607.1640625
# exp = tensor(5.2295)
# Iteration 655
# loss = 52537.71875
# exp = tensor(5.2289)
# Iteration 656
# loss = 52468.46875
# exp = tensor(5.2283)
# Iteration 657
# loss = 52399.41796875
# exp = tensor(5.2277)
# Iteration 658
# loss = 52330.51953125
# exp = tensor(5.2271)
# Iteration 659
# loss = 52261.82421875
# exp = tensor(5.2265)
# Iteration 660
# loss = 52193.328125
# exp = tensor(5.2259)
# Iteration 661
# loss = 52124.9765625
# exp = tensor(5.2253)
# Iteration 662
# loss = 52056.82421875
# exp = tensor(5.2248)
# Iteration 663
# loss = 51988.87109375
# exp = tensor(5.2242)
# Iteration 664
# loss = 51921.06640625
# exp = tensor(5.2236)
# Iteration 665
# loss = 51853.45703125
# exp = tensor(5.2230)
# Iteration 666
# loss = 51786.05078125
# exp = tensor(5.2224)
# Iteration 667
# loss = 51718.78515625
# exp = tensor(5.2218)
# Iteration 668
# loss = 51651.7109375
# exp = tensor(5.2212)
# Iteration 669
# loss = 51584.78515625
# exp = tensor(5.2207)
# Iteration 670
# loss = 51518.05078125
# exp = tensor(5.2201)
# Iteration 671
# loss = 51451.51171875
# exp = tensor(5.2195)
# Iteration 672
# loss = 51385.12109375
# exp = tensor(5.2189)
# Iteration 673
# loss = 51318.91796875
# exp = tensor(5.2183)
# Iteration 674
# loss = 51252.859375
# exp = tensor(5.2178)
# Iteration 675
# loss = 51186.9921875
# exp = tensor(5.2172)
# Iteration 676
# loss = 51121.3203125
# exp = tensor(5.2166)
# Iteration 677
# loss = 51055.78515625
# exp = tensor(5.2160)
# Iteration 678
# loss = 50990.4453125
# exp = tensor(5.2155)
# Iteration 679
# loss = 50925.23828125
# exp = tensor(5.2149)
# Iteration 680
# loss = 50860.2265625
# exp = tensor(5.2143)
# Iteration 681
# loss = 50795.34765625
# exp = tensor(5.2138)
# Iteration 682
# loss = 50730.66796875
# exp = tensor(5.2132)
# Iteration 683
# loss = 50666.1171875
# exp = tensor(5.2126)
# Iteration 684
# loss = 50601.7578125
# exp = tensor(5.2120)
# Iteration 685
# loss = 50537.58984375
# exp = tensor(5.2115)
# Iteration 686
# loss = 50473.5546875
# exp = tensor(5.2109)
# Iteration 687
# loss = 50409.7109375
# exp = tensor(5.2103)
# Iteration 688
# loss = 50345.99609375
# exp = tensor(5.2098)
# Iteration 689
# loss = 50282.47265625
# exp = tensor(5.2092)
# Iteration 690
# loss = 50219.08203125
# exp = tensor(5.2086)
# Iteration 691
# loss = 50155.8828125
# exp = tensor(5.2081)
# Iteration 692
# loss = 50092.8046875
# exp = tensor(5.2075)
# Iteration 693
# loss = 50029.92578125
# exp = tensor(5.2069)
# Iteration 694
# loss = 49967.171875
# exp = tensor(5.2064)
# Iteration 695
# loss = 49904.6015625
# exp = tensor(5.2058)
# Iteration 696
# loss = 49842.1640625
# exp = tensor(5.2053)
# Iteration 697
# loss = 49779.91015625
# exp = tensor(5.2047)
# Iteration 698
# loss = 49717.79296875
# exp = tensor(5.2041)
# Iteration 699
# loss = 49655.85546875
# exp = tensor(5.2036)
# Iteration 700
# loss = 49594.04296875
# exp = tensor(5.2030)
# Iteration 701
# loss = 49532.4140625
# exp = tensor(5.2025)
# Iteration 702
# loss = 49470.921875
# exp = tensor(5.2019)
# Iteration 703
# loss = 49409.6015625
# exp = tensor(5.2013)
# Iteration 704
# loss = 49348.4140625
# exp = tensor(5.2008)
# Iteration 705
# loss = 49287.40625
# exp = tensor(5.2002)
# Iteration 706
# loss = 49226.53125
# exp = tensor(5.1997)
# Iteration 707
# loss = 49165.78125
# exp = tensor(5.1991)
# Iteration 708
# loss = 49105.20703125
# exp = tensor(5.1986)
# Iteration 709
# loss = 49044.76171875
# exp = tensor(5.1980)
# Iteration 710
# loss = 48984.49609375
# exp = tensor(5.1975)
# Iteration 711
# loss = 48924.3515625
# exp = tensor(5.1969)
# Iteration 712
# loss = 48864.39453125
# exp = tensor(5.1964)
# Iteration 713
# loss = 48804.55859375
# exp = tensor(5.1958)
# Iteration 714
# loss = 48744.89453125
# exp = tensor(5.1953)
# Iteration 715
# loss = 48685.359375
# exp = tensor(5.1947)
# Iteration 716
# loss = 48625.94921875
# exp = tensor(5.1942)
# Iteration 717
# loss = 48566.71484375
# exp = tensor(5.1936)
# Iteration 718
# loss = 48507.6015625
# exp = tensor(5.1931)
# Iteration 719
# loss = 48448.6640625
# exp = tensor(5.1925)
# Iteration 720
# loss = 48389.85546875
# exp = tensor(5.1920)
# Iteration 721
# loss = 48331.21484375
# exp = tensor(5.1914)
# Iteration 722
# loss = 48272.69921875
# exp = tensor(5.1909)
# Iteration 723
# loss = 48214.3046875
# exp = tensor(5.1904)
# Iteration 724
# loss = 48156.0859375
# exp = tensor(5.1898)
# Iteration 725
# loss = 48097.984375
# exp = tensor(5.1893)
# Iteration 726
# loss = 48040.00390625
# exp = tensor(5.1887)
# Iteration 727
# loss = 47982.1953125
# exp = tensor(5.1882)
# Iteration 728
# loss = 47924.515625
# exp = tensor(5.1877)
# Iteration 729
# loss = 47866.99609375
# exp = tensor(5.1871)
# Iteration 730
# loss = 47809.60546875
# exp = tensor(5.1866)
# Iteration 731
# loss = 47752.328125
# exp = tensor(5.1860)
# Iteration 732
# loss = 47695.22265625
# exp = tensor(5.1855)
# Iteration 733
# loss = 47638.23828125
# exp = tensor(5.1850)
# Iteration 734
# loss = 47581.3671875
# exp = tensor(5.1844)
# Iteration 735
# loss = 47524.66796875
# exp = tensor(5.1839)
# Iteration 736
# loss = 47468.0859375
# exp = tensor(5.1834)
# Iteration 737
# loss = 47411.67578125
# exp = tensor(5.1828)
# Iteration 738
# loss = 47355.37890625
# exp = tensor(5.1823)
# Iteration 739
# loss = 47299.203125
# exp = tensor(5.1818)
# Iteration 740
# loss = 47243.1953125
# exp = tensor(5.1812)
# Iteration 741
# loss = 47187.296875
# exp = tensor(5.1807)
# Iteration 742
# loss = 47131.5234375
# exp = tensor(5.1802)
# Iteration 743
# loss = 47075.9140625
# exp = tensor(5.1796)
# Iteration 744
# loss = 47020.4140625
# exp = tensor(5.1791)
# Iteration 745
# loss = 46965.03515625
# exp = tensor(5.1786)
# Iteration 746
# loss = 46909.8203125
# exp = tensor(5.1781)
# Iteration 747
# loss = 46854.72265625
# exp = tensor(5.1775)
# Iteration 748
# loss = 46799.734375
# exp = tensor(5.1770)
# Iteration 749
# loss = 46744.91015625
# exp = tensor(5.1765)
# Iteration 750
# loss = 46690.203125
# exp = tensor(5.1760)
# Iteration 751
# loss = 46635.609375
# exp = tensor(5.1754)
# Iteration 752
# loss = 46581.12890625
# exp = tensor(5.1749)
# Iteration 753
# loss = 46526.80859375
# exp = tensor(5.1744)
# Iteration 754
# loss = 46472.60546875
# exp = tensor(5.1739)
# Iteration 755
# loss = 46418.5078125
# exp = tensor(5.1733)
# Iteration 756
# loss = 46364.578125
# exp = tensor(5.1728)
# Iteration 757
# loss = 46310.7578125
# exp = tensor(5.1723)
# Iteration 758
# loss = 46257.05078125
# exp = tensor(5.1718)
# Iteration 759
# loss = 46203.50390625
# exp = tensor(5.1713)
# Iteration 760
# loss = 46150.06640625
# exp = tensor(5.1707)
# Iteration 761
# loss = 46096.7421875
# exp = tensor(5.1702)
# Iteration 762
# loss = 46043.52734375
# exp = tensor(5.1697)
# Iteration 763
# loss = 45990.46875
# exp = tensor(5.1692)
# Iteration 764
# loss = 45937.5234375
# exp = tensor(5.1687)
# Iteration 765
# loss = 45884.6875
# exp = tensor(5.1681)
# Iteration 766
# loss = 45831.96484375
# exp = tensor(5.1676)
# Iteration 767
# loss = 45779.39453125
# exp = tensor(5.1671)
# Iteration 768
# loss = 45726.93359375
# exp = tensor(5.1666)
# Iteration 769
# loss = 45674.5859375
# exp = tensor(5.1661)
# Iteration 770
# loss = 45622.34375
# exp = tensor(5.1656)
# Iteration 771
# loss = 45570.2578125
# exp = tensor(5.1651)
# Iteration 772
# loss = 45518.28125
# exp = tensor(5.1645)
# Iteration 773
# loss = 45466.41015625
# exp = tensor(5.1640)
# Iteration 774
# loss = 45414.64453125
# exp = tensor(5.1635)
# Iteration 775
# loss = 45363.0390625
# exp = tensor(5.1630)
# Iteration 776
# loss = 45311.5390625
# exp = tensor(5.1625)
# Iteration 777
# loss = 45260.14453125
# exp = tensor(5.1620)
# Iteration 778
# loss = 45208.85546875
# exp = tensor(5.1615)
# Iteration 779
# loss = 45157.7265625
# exp = tensor(5.1610)
# Iteration 780
# loss = 45106.69921875
# exp = tensor(5.1605)
# Iteration 781
# loss = 45055.77734375
# exp = tensor(5.1600)
# Iteration 782
# loss = 45004.9609375
# exp = tensor(5.1595)
# Iteration 783
# loss = 44954.25
# exp = tensor(5.1590)
# Iteration 784
# loss = 44903.69140625
# exp = tensor(5.1584)
# Iteration 785
# loss = 44853.23828125
# exp = tensor(5.1579)
# Iteration 786
# loss = 44802.88671875
# exp = tensor(5.1574)
# Iteration 787
# loss = 44752.640625
# exp = tensor(5.1569)
# Iteration 788
# loss = 44702.5
# exp = tensor(5.1564)
# Iteration 789
# loss = 44652.51171875
# exp = tensor(5.1559)
# Iteration 790
# loss = 44602.625
# exp = tensor(5.1554)
# Iteration 791
# loss = 44552.83984375
# exp = tensor(5.1549)
# Iteration 792
# loss = 44503.16015625
# exp = tensor(5.1544)
# Iteration 793
# loss = 44453.58203125
# exp = tensor(5.1539)
# Iteration 794
# loss = 44404.15234375
# exp = tensor(5.1534)
# Iteration 795
# loss = 44354.828125
# exp = tensor(5.1529)
# Iteration 796
# loss = 44305.6015625
# exp = tensor(5.1524)
# Iteration 797
# loss = 44256.48046875
# exp = tensor(5.1519)
# Iteration 798
# loss = 44207.45703125
# exp = tensor(5.1514)
# Iteration 799
# loss = 44158.53515625
# exp = tensor(5.1509)
# Iteration 800
# loss = 44109.765625
# exp = tensor(5.1504)
# Iteration 801
# loss = 44061.09375
# exp = tensor(5.1500)
# Iteration 802
# loss = 44012.5234375
# exp = tensor(5.1495)
# Iteration 803
# loss = 43964.0546875
# exp = tensor(5.1490)
# Iteration 804
# loss = 43915.68359375
# exp = tensor(5.1485)
# Iteration 805
# loss = 43867.41015625
# exp = tensor(5.1480)
# Iteration 806
# loss = 43819.28515625
# exp = tensor(5.1475)
# Iteration 807
# loss = 43771.26171875
# exp = tensor(5.1470)
# Iteration 808
# loss = 43723.3359375
# exp = tensor(5.1465)
# Iteration 809
# loss = 43675.5078125
# exp = tensor(5.1460)
# Iteration 810
# loss = 43627.78125
# exp = tensor(5.1455)
# Iteration 811
# loss = 43580.15234375
# exp = tensor(5.1450)
# Iteration 812
# loss = 43532.62109375
# exp = tensor(5.1445)
# Iteration 813
# loss = 43485.234375
# exp = tensor(5.1440)
# Iteration 814
# loss = 43437.9453125
# exp = tensor(5.1436)
# Iteration 815
# loss = 43390.75390625
# exp = tensor(5.1431)
# Iteration 816
# loss = 43343.66015625
# exp = tensor(5.1426)
# Iteration 817
# loss = 43296.6640625
# exp = tensor(5.1421)
# Iteration 818
# loss = 43249.76171875
# exp = tensor(5.1416)
# Iteration 819
# loss = 43202.9609375
# exp = tensor(5.1411)
# Iteration 820
# loss = 43156.25390625
# exp = tensor(5.1406)
# Iteration 821
# loss = 43109.6875
# exp = tensor(5.1402)
# Iteration 822
# loss = 43063.21875
# exp = tensor(5.1397)
# Iteration 823
# loss = 43016.84765625
# exp = tensor(5.1392)
# Iteration 824
# loss = 42970.5703125
# exp = tensor(5.1387)
# Iteration 825
# loss = 42924.390625
# exp = tensor(5.1382)
# Iteration 826
# loss = 42878.30078125
# exp = tensor(5.1377)
# Iteration 827
# loss = 42832.3125
# exp = tensor(5.1373)
# Iteration 828
# loss = 42786.41796875
# exp = tensor(5.1368)
# Iteration 829
# loss = 42740.61328125
# exp = tensor(5.1363)
# Iteration 830
# loss = 42694.90625
# exp = tensor(5.1358)
# Iteration 831
# loss = 42649.33984375
# exp = tensor(5.1353)
# Iteration 832
# loss = 42603.86328125
# exp = tensor(5.1349)
# Iteration 833
# loss = 42558.484375
# exp = tensor(5.1344)
# Iteration 834
# loss = 42513.19921875
# exp = tensor(5.1339)
# Iteration 835
# loss = 42468.00390625
# exp = tensor(5.1334)
# Iteration 836
# loss = 42422.90234375
# exp = tensor(5.1329)
# Iteration 837
# loss = 42377.8984375
# exp = tensor(5.1325)
# Iteration 838
# loss = 42332.984375
# exp = tensor(5.1320)
# Iteration 839
# loss = 42288.16015625
# exp = tensor(5.1315)
# Iteration 840
# loss = 42243.43359375
# exp = tensor(5.1310)
# Iteration 841
# loss = 42198.796875
# exp = tensor(5.1306)
# Iteration 842
# loss = 42154.25390625
# exp = tensor(5.1301)
# Iteration 843
# loss = 42109.80078125
# exp = tensor(5.1296)
# Iteration 844
# loss = 42065.48046875
# exp = tensor(5.1292)
# Iteration 845
# loss = 42021.2578125
# exp = tensor(5.1287)
# Iteration 846
# loss = 41977.12109375
# exp = tensor(5.1282)
# Iteration 847
# loss = 41933.078125
# exp = tensor(5.1277)
# Iteration 848
# loss = 41889.125
# exp = tensor(5.1273)
# Iteration 849
# loss = 41845.26171875
# exp = tensor(5.1268)
# Iteration 850
# loss = 41801.4921875
# exp = tensor(5.1263)
# Iteration 851
# loss = 41757.8125
# exp = tensor(5.1259)
# Iteration 852
# loss = 41714.21875
# exp = tensor(5.1254)
# Iteration 853
# loss = 41670.71875
# exp = tensor(5.1249)
# Iteration 854
# loss = 41627.3046875
# exp = tensor(5.1245)
# Iteration 855
# loss = 41583.98046875
# exp = tensor(5.1240)
# Iteration 856
# loss = 41540.75
# exp = tensor(5.1235)
# Iteration 857
# loss = 41497.60546875
# exp = tensor(5.1231)
# Iteration 858
# loss = 41454.55078125
# exp = tensor(5.1226)
# Iteration 859
# loss = 41411.58203125
# exp = tensor(5.1221)
# Iteration 860
# loss = 41368.70703125
# exp = tensor(5.1217)
# Iteration 861
# loss = 41325.91796875
# exp = tensor(5.1212)
# Iteration 862
# loss = 41283.21484375
# exp = tensor(5.1207)
# Iteration 863
# loss = 41240.6015625
# exp = tensor(5.1203)
# Iteration 864
# loss = 41198.0703125
# exp = tensor(5.1198)
# Iteration 865
# loss = 41155.63671875
# exp = tensor(5.1193)
# Iteration 866
# loss = 41113.2890625
# ...
# loss = 4096.23828125
# exp = tensor(4.0821)
# Iteration 9734
# loss = 4095.82080078125
# exp = tensor(4.0821)
# Iteration 9735
# loss = 4095.403076171875
# exp = tensor(4.0820)
# Iteration 9736
# loss = 4094.985595703125
# exp = tensor(4.0820)
# Iteration 9737
# loss = 4094.56787109375
# exp = tensor(4.0819)
# Iteration 9738
# loss = 4094.150390625
# exp = tensor(4.0819)
# Iteration 9739
# loss = 4093.73291015625
# exp = tensor(4.0819)
# Iteration 9740
# loss = 4093.315673828125
# exp = tensor(4.0818)
# Iteration 9741
# loss = 4092.8984375
# exp = tensor(4.0818)
# Iteration 9742
# loss = 4092.481201171875
# exp = tensor(4.0817)
# Iteration 9743
# loss = 4092.063720703125
# exp = tensor(4.0817)
# Iteration 9744
# loss = 4091.646484375
# exp = tensor(4.0816)
# Iteration 9745
# loss = 4091.2294921875
# exp = tensor(4.0816)
# Iteration 9746
# loss = 4090.81201171875
# exp = tensor(4.0815)
# Iteration 9747
# loss = 4090.395263671875
# exp = tensor(4.0815)
# Iteration 9748
# loss = 4089.977783203125
# exp = tensor(4.0814)
# Iteration 9749
# loss = 4089.56103515625
# exp = tensor(4.0814)
# Iteration 9750
# loss = 4089.143798828125
# exp = tensor(4.0813)
# Iteration 9751
# loss = 4088.72705078125
# exp = tensor(4.0813)
# Iteration 9752
# loss = 4088.31005859375
# exp = tensor(4.0813)
# Iteration 9753
# loss = 4087.8935546875
# exp = tensor(4.0812)
# Iteration 9754
# loss = 4087.4765625
# exp = tensor(4.0812)
# Iteration 9755
# loss = 4087.059814453125
# exp = tensor(4.0811)
# Iteration 9756
# loss = 4086.642822265625
# exp = tensor(4.0811)
# Iteration 9757
# loss = 4086.226318359375
# exp = tensor(4.0810)
# Iteration 9758
# loss = 4085.8095703125
# exp = tensor(4.0810)
# Iteration 9759
# loss = 4085.393310546875
# exp = tensor(4.0809)
# Iteration 9760
# loss = 4084.976318359375
# exp = tensor(4.0809)
# Iteration 9761
# loss = 4084.56005859375
# exp = tensor(4.0808)
# Iteration 9762
# loss = 4084.147705078125
# exp = tensor(4.0808)
# Iteration 9763
# loss = 4083.73583984375
# exp = tensor(4.0808)
# Iteration 9764
# loss = 4083.32373046875
# exp = tensor(4.0807)
# Iteration 9765
# loss = 4082.911865234375
# exp = tensor(4.0807)
# Iteration 9766
# loss = 4082.499755859375
# exp = tensor(4.0806)
# Iteration 9767
# loss = 4082.087646484375
# exp = tensor(4.0806)
# Iteration 9768
# loss = 4081.676025390625
# exp = tensor(4.0805)
# Iteration 9769
# loss = 4081.263916015625
# exp = tensor(4.0805)
# Iteration 9770
# loss = 4080.852294921875
# exp = tensor(4.0804)
# Iteration 9771
# loss = 4080.440185546875
# exp = tensor(4.0804)
# Iteration 9772
# loss = 4080.028564453125
# exp = tensor(4.0803)
# Iteration 9773
# loss = 4079.6171875
# exp = tensor(4.0803)
# Iteration 9774
# loss = 4079.205322265625
# exp = tensor(4.0803)
# Iteration 9775
# loss = 4078.793701171875
# exp = tensor(4.0802)
# Iteration 9776
# loss = 4078.382568359375
# exp = tensor(4.0802)
# Iteration 9777
# loss = 4077.970947265625
# exp = tensor(4.0801)
# Iteration 9778
# loss = 4077.559326171875
# exp = tensor(4.0801)
# Iteration 9779
# loss = 4077.14794921875
# exp = tensor(4.0800)
# Iteration 9780
# loss = 4076.736572265625
# exp = tensor(4.0800)
# Iteration 9781
# loss = 4076.324951171875
# exp = tensor(4.0799)
# Iteration 9782
# loss = 4075.913818359375
# exp = tensor(4.0799)
# Iteration 9783
# loss = 4075.50244140625
# exp = tensor(4.0798)
# Iteration 9784
# loss = 4075.09130859375
# exp = tensor(4.0798)
# Iteration 9785
# loss = 4074.68017578125
# exp = tensor(4.0798)
# Iteration 9786
# loss = 4074.26904296875
# exp = tensor(4.0797)
# Iteration 9787
# loss = 4073.857666015625
# exp = tensor(4.0797)
# Iteration 9788
# loss = 4073.44677734375
# exp = tensor(4.0796)
# Iteration 9789
# loss = 4073.03564453125
# exp = tensor(4.0796)
# Iteration 9790
# loss = 4072.625
# exp = tensor(4.0795)
# Iteration 9791
# loss = 4072.2138671875
# exp = tensor(4.0795)
# Iteration 9792
# loss = 4071.802978515625
# exp = tensor(4.0794)
# Iteration 9793
# loss = 4071.39208984375
# exp = tensor(4.0794)
# Iteration 9794
# loss = 4070.9814453125
# exp = tensor(4.0793)
# Iteration 9795
# loss = 4070.570556640625
# exp = tensor(4.0793)
# Iteration 9796
# loss = 4070.15966796875
# exp = tensor(4.0793)
# Iteration 9797
# loss = 4069.749267578125
# exp = tensor(4.0792)
# Iteration 9798
# loss = 4069.338623046875
# exp = tensor(4.0792)
# Iteration 9799
# loss = 4068.927978515625
# exp = tensor(4.0791)
# Iteration 9800
# loss = 4068.517333984375
# exp = tensor(4.0791)
# Iteration 9801
# loss = 4068.106689453125
# exp = tensor(4.0790)
# Iteration 9802
# loss = 4067.6962890625
# exp = tensor(4.0790)
# Iteration 9803
# loss = 4067.285888671875
# exp = tensor(4.0789)
# Iteration 9804
# loss = 4066.875244140625
# exp = tensor(4.0789)
# Iteration 9805
# loss = 4066.465087890625
# exp = tensor(4.0789)
# Iteration 9806
# loss = 4066.054931640625
# exp = tensor(4.0788)
# Iteration 9807
# loss = 4065.64453125
# exp = tensor(4.0788)
# Iteration 9808
# loss = 4065.234375
# exp = tensor(4.0787)
# Iteration 9809
# loss = 4064.82421875
# exp = tensor(4.0787)
# Iteration 9810
# loss = 4064.4140625
# exp = tensor(4.0786)
# Iteration 9811
# loss = 4064.00390625
# exp = tensor(4.0786)
# Iteration 9812
# loss = 4063.59375
# exp = tensor(4.0785)
# Iteration 9813
# loss = 4063.183837890625
# exp = tensor(4.0785)
# Iteration 9814
# loss = 4062.77392578125
# exp = tensor(4.0784)
# Iteration 9815
# loss = 4062.364013671875
# exp = tensor(4.0784)
# Iteration 9816
# loss = 4061.953857421875
# exp = tensor(4.0784)
# Iteration 9817
# loss = 4061.5439453125
# exp = tensor(4.0783)
# Iteration 9818
# loss = 4061.13427734375
# exp = tensor(4.0783)
# Iteration 9819
# loss = 4060.72412109375
# exp = tensor(4.0782)
# Iteration 9820
# loss = 4060.314453125
# exp = tensor(4.0782)
# Iteration 9821
# loss = 4059.9052734375
# exp = tensor(4.0781)
# Iteration 9822
# loss = 4059.495361328125
# exp = tensor(4.0781)
# Iteration 9823
# loss = 4059.0859375
# exp = tensor(4.0780)
# Iteration 9824
# loss = 4058.676025390625
# exp = tensor(4.0780)
# Iteration 9825
# loss = 4058.2666015625
# exp = tensor(4.0779)
# Iteration 9826
# loss = 4057.857177734375
# exp = tensor(4.0779)
# Iteration 9827
# loss = 4057.447509765625
# exp = tensor(4.0779)
# Iteration 9828
# loss = 4057.038330078125
# exp = tensor(4.0778)
# Iteration 9829
# loss = 4056.62890625
# exp = tensor(4.0778)
# Iteration 9830
# loss = 4056.219482421875
# exp = tensor(4.0777)
# Iteration 9831
# loss = 4055.810302734375
# exp = tensor(4.0777)
# Iteration 9832
# loss = 4055.401123046875
# exp = tensor(4.0776)
# Iteration 9833
# loss = 4054.99169921875
# exp = tensor(4.0776)
# Iteration 9834
# loss = 4054.58251953125
# exp = tensor(4.0775)
# Iteration 9835
# loss = 4054.173583984375
# exp = tensor(4.0775)
# Iteration 9836
# loss = 4053.7646484375
# exp = tensor(4.0774)
# Iteration 9837
# loss = 4053.355224609375
# exp = tensor(4.0774)
# Iteration 9838
# loss = 4052.9462890625
# exp = tensor(4.0774)
# Iteration 9839
# loss = 4052.537109375
# exp = tensor(4.0773)
# Iteration 9840
# loss = 4052.128662109375
# exp = tensor(4.0773)
# Iteration 9841
# loss = 4051.7197265625
# exp = tensor(4.0772)
# Iteration 9842
# loss = 4051.310791015625
# exp = tensor(4.0772)
# Iteration 9843
# loss = 4050.902099609375
# exp = tensor(4.0771)
# Iteration 9844
# loss = 4050.4931640625
# exp = tensor(4.0771)
# Iteration 9845
# loss = 4050.084228515625
# exp = tensor(4.0770)
# Iteration 9846
# loss = 4049.67578125
# exp = tensor(4.0770)
# Iteration 9847
# loss = 4049.26708984375
# exp = tensor(4.0769)
# Iteration 9848
# loss = 4048.858642578125
# exp = tensor(4.0769)
# Iteration 9849
# loss = 4048.449951171875
# exp = tensor(4.0769)
# Iteration 9850
# loss = 4048.04150390625
# exp = tensor(4.0768)
# Iteration 9851
# loss = 4047.6328125
# exp = tensor(4.0768)
# Iteration 9852
# loss = 4047.224609375
# exp = tensor(4.0767)
# Iteration 9853
# loss = 4046.816162109375
# exp = tensor(4.0767)
# Iteration 9854
# loss = 4046.40771484375
# exp = tensor(4.0766)
# Iteration 9855
# loss = 4045.999267578125
# exp = tensor(4.0766)
# Iteration 9856
# loss = 4045.59130859375
# exp = tensor(4.0765)
# Iteration 9857
# loss = 4045.18310546875
# exp = tensor(4.0765)
# Iteration 9858
# loss = 4044.774658203125
# exp = tensor(4.0764)
# Iteration 9859
# loss = 4044.36669921875
# exp = tensor(4.0764)
# Iteration 9860
# loss = 4043.95849609375
# exp = tensor(4.0764)
# Iteration 9861
# loss = 4043.550537109375
# exp = tensor(4.0763)
# Iteration 9862
# loss = 4043.142822265625
# exp = tensor(4.0763)
# Iteration 9863
# loss = 4042.734619140625
# exp = tensor(4.0762)
# Iteration 9864
# loss = 4042.32666015625
# exp = tensor(4.0762)
# Iteration 9865
# loss = 4041.918701171875
# exp = tensor(4.0761)
# Iteration 9866
# loss = 4041.51513671875
# exp = tensor(4.0761)
# Iteration 9867
# loss = 4041.111572265625
# exp = tensor(4.0760)
# Iteration 9868
# loss = 4040.708251953125
# exp = tensor(4.0760)
# Iteration 9869
# loss = 4040.304931640625
# exp = tensor(4.0760)
# Iteration 9870
# loss = 4039.9013671875
# exp = tensor(4.0759)
# Iteration 9871
# loss = 4039.497802734375
# exp = tensor(4.0759)
# Iteration 9872
# loss = 4039.094482421875
# exp = tensor(4.0758)
# Iteration 9873
# loss = 4038.69140625
# exp = tensor(4.0758)
# Iteration 9874
# loss = 4038.2880859375
# exp = tensor(4.0757)
# Iteration 9875
# loss = 4037.885009765625
# exp = tensor(4.0757)
# Iteration 9876
# loss = 4037.481689453125
# exp = tensor(4.0756)
# Iteration 9877
# loss = 4037.07861328125
# exp = tensor(4.0756)
# Iteration 9878
# loss = 4036.675537109375
# exp = tensor(4.0756)
# Iteration 9879
# loss = 4036.272216796875
# exp = tensor(4.0755)
# Iteration 9880
# loss = 4035.869384765625
# exp = tensor(4.0755)
# Iteration 9881
# loss = 4035.46630859375
# exp = tensor(4.0754)
# Iteration 9882
# loss = 4035.063720703125
# exp = tensor(4.0754)
# Iteration 9883
# loss = 4034.66064453125
# exp = tensor(4.0753)
# Iteration 9884
# loss = 4034.2578125
# exp = tensor(4.0753)
# Iteration 9885
# loss = 4033.85498046875
# exp = tensor(4.0752)
# Iteration 9886
# loss = 4033.4521484375
# exp = tensor(4.0752)
# Iteration 9887
# loss = 4033.049560546875
# exp = tensor(4.0751)
# Iteration 9888
# loss = 4032.646728515625
# exp = tensor(4.0751)
# Iteration 9889
# loss = 4032.244140625
# exp = tensor(4.0751)
# Iteration 9890
# loss = 4031.841552734375
# exp = tensor(4.0750)
# Iteration 9891
# loss = 4031.43896484375
# exp = tensor(4.0750)
# Iteration 9892
# loss = 4031.03662109375
# exp = tensor(4.0749)
# Iteration 9893
# loss = 4030.634033203125
# exp = tensor(4.0749)
# Iteration 9894
# loss = 4030.231689453125
# exp = tensor(4.0748)
# Iteration 9895
# loss = 4029.829345703125
# exp = tensor(4.0748)
# Iteration 9896
# loss = 4029.427001953125
# exp = tensor(4.0747)
# Iteration 9897
# loss = 4029.0244140625
# exp = tensor(4.0747)
# Iteration 9898
# loss = 4028.622314453125
# exp = tensor(4.0747)
# Iteration 9899
# loss = 4028.219970703125
# exp = tensor(4.0746)
# Iteration 9900
# loss = 4027.81787109375
# exp = tensor(4.0746)
# Iteration 9901
# loss = 4027.415771484375
# exp = tensor(4.0745)
# Iteration 9902
# loss = 4027.01318359375
# exp = tensor(4.0745)
# Iteration 9903
# loss = 4026.611572265625
# exp = tensor(4.0744)
# Iteration 9904
# loss = 4026.209228515625
# exp = tensor(4.0744)
# Iteration 9905
# loss = 4025.8076171875
# exp = tensor(4.0743)
# Iteration 9906
# loss = 4025.405517578125
# exp = tensor(4.0743)
# Iteration 9907
# loss = 4025.00341796875
# exp = tensor(4.0743)
# Iteration 9908
# loss = 4024.6015625
# exp = tensor(4.0742)
# Iteration 9909
# loss = 4024.19970703125
# exp = tensor(4.0742)
# Iteration 9910
# loss = 4023.7978515625
# exp = tensor(4.0741)
# Iteration 9911
# loss = 4023.39599609375
# exp = tensor(4.0741)
# Iteration 9912
# loss = 4022.994384765625
# exp = tensor(4.0740)
# Iteration 9913
# loss = 4022.5927734375
# exp = tensor(4.0740)
# Iteration 9914
# loss = 4022.19091796875
# exp = tensor(4.0739)
# Iteration 9915
# loss = 4021.789306640625
# exp = tensor(4.0739)
# Iteration 9916
# loss = 4021.38818359375
# exp = tensor(4.0738)
# Iteration 9917
# loss = 4020.986328125
# exp = tensor(4.0738)
# Iteration 9918
# loss = 4020.5849609375
# exp = tensor(4.0738)
# Iteration 9919
# loss = 4020.183349609375
# exp = tensor(4.0737)
# Iteration 9920
# loss = 4019.781982421875
# exp = tensor(4.0737)
# Iteration 9921
# loss = 4019.380859375
# exp = tensor(4.0736)
# Iteration 9922
# loss = 4018.979248046875
# exp = tensor(4.0736)
# Iteration 9923
# loss = 4018.577880859375
# exp = tensor(4.0735)
# Iteration 9924
# loss = 4018.1767578125
# exp = tensor(4.0735)
# Iteration 9925
# loss = 4017.775634765625
# exp = tensor(4.0734)
# Iteration 9926
# loss = 4017.37451171875
# exp = tensor(4.0734)
# Iteration 9927
# loss = 4016.97314453125
# exp = tensor(4.0734)
# Iteration 9928
# loss = 4016.572265625
# exp = tensor(4.0733)
# Iteration 9929
# loss = 4016.171142578125
# exp = tensor(4.0733)
# Iteration 9930
# loss = 4015.770263671875
# exp = tensor(4.0732)
# Iteration 9931
# loss = 4015.369140625
# exp = tensor(4.0732)
# Iteration 9932
# loss = 4014.968017578125
# exp = tensor(4.0731)
# Iteration 9933
# loss = 4014.5673828125
# exp = tensor(4.0731)
# Iteration 9934
# loss = 4014.16650390625
# exp = tensor(4.0730)
# Iteration 9935
# loss = 4013.765869140625
# exp = tensor(4.0730)
# Iteration 9936
# loss = 4013.364990234375
# exp = tensor(4.0730)
# Iteration 9937
# loss = 4012.964111328125
# exp = tensor(4.0729)
# Iteration 9938
# loss = 4012.5634765625
# exp = tensor(4.0729)
# Iteration 9939
# loss = 4012.162841796875
# exp = tensor(4.0728)
# Iteration 9940
# loss = 4011.762451171875
# exp = tensor(4.0728)
# Iteration 9941
# loss = 4011.361572265625
# exp = tensor(4.0727)
# Iteration 9942
# loss = 4010.961181640625
# exp = tensor(4.0727)
# Iteration 9943
# loss = 4010.560791015625
# exp = tensor(4.0726)
# Iteration 9944
# loss = 4010.16015625
# exp = tensor(4.0726)
# Iteration 9945
# loss = 4009.759765625
# exp = tensor(4.0725)
# Iteration 9946
# loss = 4009.359619140625
# exp = tensor(4.0725)
# Iteration 9947
# loss = 4008.958984375
# exp = tensor(4.0725)
# Iteration 9948
# loss = 4008.558837890625
# exp = tensor(4.0724)
# Iteration 9949
# loss = 4008.158447265625
# exp = tensor(4.0724)
# Iteration 9950
# loss = 4007.758544921875
# exp = tensor(4.0723)
# Iteration 9951
# loss = 4007.358154296875
# exp = tensor(4.0723)
# Iteration 9952
# loss = 4006.9580078125
# exp = tensor(4.0722)
# Iteration 9953
# loss = 4006.55810546875
# exp = tensor(4.0722)
# Iteration 9954
# loss = 4006.15771484375
# exp = tensor(4.0721)
# Iteration 9955
# loss = 4005.7578125
# exp = tensor(4.0721)
# Iteration 9956
# loss = 4005.35791015625
# exp = tensor(4.0721)
# Iteration 9957
# loss = 4004.9580078125
# exp = tensor(4.0720)
# Iteration 9958
# loss = 4004.55810546875
# exp = tensor(4.0720)
# Iteration 9959
# loss = 4004.158203125
# exp = tensor(4.0719)
# Iteration 9960
# loss = 4003.758056640625
# exp = tensor(4.0719)
# Iteration 9961
# loss = 4003.3583984375
# exp = tensor(4.0718)
# Iteration 9962
# loss = 4002.958740234375
# exp = tensor(4.0718)
# Iteration 9963
# loss = 4002.559326171875
# exp = tensor(4.0717)
# Iteration 9964
# loss = 4002.159423828125
# exp = tensor(4.0717)
# Iteration 9965
# loss = 4001.760009765625
# exp = tensor(4.0717)
# Iteration 9966
# loss = 4001.360107421875
# exp = tensor(4.0716)
# Iteration 9967
# loss = 4000.960693359375
# exp = tensor(4.0716)
# Iteration 9968
# loss = 4000.561279296875
# exp = tensor(4.0715)
# Iteration 9969
# loss = 4000.161865234375
# exp = tensor(4.0715)
# Iteration 9970
# loss = 3999.762451171875
# exp = tensor(4.0714)
# Iteration 9971
# loss = 3999.363037109375
# exp = tensor(4.0714)
# Iteration 9972
# loss = 3998.963623046875
# exp = tensor(4.0713)
# Iteration 9973
# loss = 3998.564453125
# exp = tensor(4.0713)
# Iteration 9974
# loss = 3998.16943359375
# exp = tensor(4.0712)
# Iteration 9975
# loss = 3997.7744140625
# exp = tensor(4.0712)
# Iteration 9976
# loss = 3997.37939453125
# exp = tensor(4.0712)
# Iteration 9977
# loss = 3996.984619140625
# exp = tensor(4.0711)
# Iteration 9978
# loss = 3996.58984375
# exp = tensor(4.0711)
# Iteration 9979
# loss = 3996.19482421875
# exp = tensor(4.0710)
# Iteration 9980
# loss = 3995.800048828125
# exp = tensor(4.0710)
# Iteration 9981
# loss = 3995.4052734375
# exp = tensor(4.0709)
# Iteration 9982
# loss = 3995.0107421875
# exp = tensor(4.0709)
# Iteration 9983
# loss = 3994.615966796875
# exp = tensor(4.0708)
# Iteration 9984
# loss = 3994.22119140625
# exp = tensor(4.0708)
# Iteration 9985
# loss = 3993.82666015625
# exp = tensor(4.0708)
# Iteration 9986
# loss = 3993.432373046875
# exp = tensor(4.0707)
# Iteration 9987
# loss = 3993.03759765625
# exp = tensor(4.0707)
# Iteration 9988
# loss = 3992.643310546875
# exp = tensor(4.0706)
# Iteration 9989
# loss = 3992.248779296875
# exp = tensor(4.0706)
# Iteration 9990
# loss = 3991.854248046875
# exp = tensor(4.0705)
# Iteration 9991
# loss = 3991.460205078125
# exp = tensor(4.0705)
# Iteration 9992
# loss = 3991.06591796875
# exp = tensor(4.0705)
# Iteration 9993
# loss = 3990.67138671875
# exp = tensor(4.0704)
# Iteration 9994
# loss = 3990.277099609375
# exp = tensor(4.0704)
# Iteration 9995
# loss = 3989.8828125
# exp = tensor(4.0703)
# Iteration 9996
# loss = 3989.489013671875
# exp = tensor(4.0703)
# Iteration 9997
# loss = 3989.0947265625
# exp = tensor(4.0702)
# Iteration 9998
# loss = 3988.700439453125
# exp = tensor(4.0702)
# Iteration 9999
# loss = 3988.306640625
# exp = tensor(4.0701)

# %% [markdown]
# Tensorflow model

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy import io
import torch 
import os
from sklearn import linear_model


rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [12, 12]

# %%
# dogs vs. cats
dogdata_w_mat = io.loadmat(os.path.join('..','DATA','dogData_w.mat'))
catdata_w_mat = io.loadmat(os.path.join('..','DATA','catData_w.mat'))

dog_wave = dogdata_w_mat['dog_wave']
cat_wave = catdata_w_mat['cat_wave']

CD = np.concatenate((dog_wave,cat_wave),axis=1)

train = np.concatenate((dog_wave[:,:60],cat_wave[:,:60]),axis=1)
test = np.concatenate((dog_wave[:,60:80],cat_wave[:,60:80]),axis=1)
label = np.repeat(np.array([1,-1]),60)

A = label @ np.linalg.pinv(train)
test_labels = np.sign(A@test)

# %%
lasso = linear_model.Lasso().fit(train.T,label)
A_lasso = lasso.coef_
test_labels_lasso = np.sign(A_lasso@test)

# %%
fig,axs = plt.subplots(4,1)
axs[0].bar(range(len(test_labels)),test_labels)
axs[1].bar(range(len(A)),A)
axs[2].bar(range(len(test_labels_lasso)),test_labels_lasso)
axs[3].bar(range(len(A_lasso)),A_lasso)


plt.show()

# %%
fig,axs = plt.subplots(2,2)
axs = axs.reshape(-1)
A2 = np.flipud(np.reshape(A,(32,32)))
A2_lasso = np.flipud(np.reshape(A_lasso,(32,32)))
axs[0].pcolor(np.rot90(A2),cmap='gray')
axs[1].pcolor(np.rot90(A2_lasso),cmap='gray')


plt.show()
