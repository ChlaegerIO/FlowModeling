# %% [markdown]
# Dog vs. Cats example

# %%
from scipy import io
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
from torchvision import datasets, transforms

# dogs vs. cats
dogdata_w_mat = io.loadmat(os.path.join('..','DATA','dogData_w.mat'))
catdata_w_mat = io.loadmat(os.path.join('..','DATA','catData_w.mat'))

dog_wave = dogdata_w_mat['dog_wave']
cat_wave = catdata_w_mat['cat_wave']

CD = np.concatenate((dog_wave,cat_wave),axis=1)

train = np.concatenate((dog_wave[:,:60],cat_wave[:,:60]),axis=1)
test = np.concatenate((dog_wave[:,60:80],cat_wave[:,60:80]),axis=1)
label_train = np.repeat(np.array([1,-1]),60)
label_test = np.repeat(np.array([1,-1]),20)

print(train.shape[0], train.shape[1])
# Out:
# 1024 120

# %%
# print progress, possibly faster than progress bar
def print_progress(epoch, batch_id, accuracy, loss):
    progress = '='* int((10. * batch_id / len(train_data)))
    progress += '>'
    if batch_id == 1:
        print('Train Epoche {}: {}% [{}]\t accuracy: {:.6f}, loss: {:.6f}'.format(
            epoch, int(100. * batch_id / len(train_data)),progress, accuracy, loss.item()), end='')
    else:
        print('\rTrain Epoche {}: {}% [{}]\t accuracy: {:.6f}, loss: {:.6f}'.format(
            epoch, int(100. * batch_id / len(train_data)),progress, accuracy, loss.item()), end='', flush = True)

# %%
# shuffle data
idx_col_d = np.random.permutation(train.shape[1])
train_data_list = np.ones((train.shape[0], idx_col_d.shape[0]))
label_data_list = np.ones((2, idx_col_d.shape[0]))
train_data_list[:,0:] = train[:,idx_col_d[:]]
print(train_data_list.shape)
label_data_list[0:] = label_train[idx_col_d[:]]
for j in range(0,label_data_list.shape[1]):         # dog: first row[0], cat: second row[1]
    if label_data_list[0,j] == 1:
        label_data_list[1,j] = 0                    # 1=dog, -1=cat
    elif label_data_list[0,j] == -1:
        label_data_list[0,j] = 0
        label_data_list[1,j] = 1
        
# every row is a data tensor
train_data = []
label_data = []
for c in range(0,train_data_list.shape[1]):
    train_data.append(torch.from_numpy(train_data_list[:,c]))     # changes row, col
    label_data.append(torch.from_numpy(label_data_list[:,c]))
print('Data: row',len(train_data),'col:', len(train_data[0]))
print('Label: row',len(label_data),'col:', len(label_data[0]))

# shuffle test data
idx_col_t = np.random.permutation(test.shape[1])
test_data_list = np.ones((test.shape[0], idx_col_t.shape[0]))
test_data_list[:,0:] = test[:,idx_col_t[:]]
label_test_list = np.ones((2, idx_col_t.shape[0]))
label_test_list[0:] = label_test[idx_col_t[:]]
for j in range(0,label_test_list.shape[1]):
    if label_test_list[0,j] == 1:
        label_test_list[1,j] = 0
    elif label_test_list[0,j] == -1:
        label_test_list[0,j] = 0
        label_test_list[1,j] = 1

# every row is a test tensor
test_data = []
label_test_final = []
for c in range(0,test_data_list.shape[1]):
    test_data.append(torch.from_numpy(test_data_list[:,c]))     # changes row, col
    label_test_final.append(torch.from_numpy(label_test_list[:,c]))
print('Test: row',len(test_data),'col:', len(test_data[0]))
print('Label: row',len(label_test_final),'col:', len(label_test_final[0]))
# Out:
# (1024, 120)
# Data: row 120 col: 1024
# Label: row 120 col: 2
# Test: row 40 col: 1024
# Label: row 40 col: 2
# tensor([ 2.,  5.,  2.,  ..., 11., 10.,  6.], dtype=torch.float64)

# %%
class net(nn.Module):
    def __init__(self):
        super(net, self).__init__()
        self.conv_dropout = nn.Dropout()
        self.fc2 = nn.Linear(1024, 2)
    
    def forward(self,x):
        x = F.relu(x)
        x = self.conv_dropout(x)
        x = F.relu(x)
        #print('test:',x.shape)
        x = self.fc2(x)
        #print('test:',x.shape)
        
        return F.log_softmax(x, dim=0)
        

# model
model = net()
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.8)   # momentum [0,1]

# training
def train(epoch):
    model.train()
    batch_id = 1
    # 1 - 120 train data with label_data
    for r in range(0,len(train_data)):
        optimizer.zero_grad()
        
        # forward pass
        data_row = train_data[r].float()
        out = model(data_row)
        
        #calculate loss
        label_row = label_data[r].long()
        loss = F.nll_loss(out, label_row)          # nn.CrossEntropyLoss(), F.nll_loss is better
        loss.backward()
        optimizer.step()
        # display training progress
        accuracy = 100. * batch_id / len(train_data)
        print_progress(epoch, batch_id, accuracy, loss)
        torch.save(net, 'data_figures_nn/MyNet_DogCat.pt')
        batch_id += 1

        
# test the predictions
def test():
    model.eval()
    loss = 0
    correct = 0
    for r in range(0,len(test_data)):
        data_row = test_data[r].float()
        out = model(data_row)
                   
        label_row = label_data[r].long()
        loss += F.nll_loss(out, label_row, size_average=False).item()
        prediction = out.data.max(0, keepdim=True)
        print('prediction',out.data)
        print('prediction',prediction)

        if prediction == label_row:
            correct +=1
        #correct += prediction.eq(label_row.data.view_as(prediction)).sum()
    
    loss = loss / len(test_data)
    print('average loss: ', loss)
    print('accuracy: ', int(100.*correct/len(test_data)), '%')
        
for epoch in range(1,5):
        train(epoch)
        print('new epoch', epoch)
        test()
# Out:
# Train Epoche 1: 100% [==========>]	 accuracy: 100.000000, loss: 120431.703125new epoch 1
# prediction tensor([      0.0000, -249013.9375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -279043.6250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -323087.6875])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -98058.7266])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -366329.6250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -282646.7500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -419787.8125])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-98549.5000,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -453367.4375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -229038.2656])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-19886.6875,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -337173.5625])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -406428.2500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -401553.0312])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -225949.3906])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -172865.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -286730.7500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -391499.0938])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -306995.4062])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -386502.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -155650.4688])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -193566.2031])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -115870.1562])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -438812.3750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -370221.6562])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -84615.0547])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -207421.5469])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0., -268505.])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0., -299212.])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -158434.3906])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -184482.9688])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -334411.3750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -107894.2344])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -211119.7188])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -239627.9219])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -424543.2812])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -174539.0781])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -187484.5625])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -267181.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -32918.2734])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# average loss:  153073.924609375
# accuracy:  0 %
# Train Epoche 2: 100% [==========>]	 accuracy: 100.000000, loss: 0.00000000new epoch 2
# prediction tensor([      0.0000, -323378.7188])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -488097.3750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -538688.2500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -219948.4531])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -606805.3125])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -553143.8750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -696466.2500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -13408.8008])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -718184.6250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -397288.6875])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -104691.9844])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -471299.1875])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -572954.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -591703.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0., -360651.])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -291890.8750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -452460.4375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -418780.0938])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -513024.9062])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -576401.3750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -310939.1250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -298373.8750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -287180.3750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0., -726290.])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -634986.1250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -52063.8242])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -430335.7500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -382198.4375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -356468.8125])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -302636.7500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -380693.3750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -632298.7500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -224110.2500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -343912.8438])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -381531.0625])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -651458.3750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -369413.9062])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -214972.1562])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -541089.9375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -175777.9375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# average loss:  252524.765625
# accuracy:  0 %
# Train Epoche 3: 100% [==========>]	 accuracy: 100.000000, loss: 0.00000050new epoch 3
# prediction tensor([      0.0000, -237290.0312])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -212080.0312])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -287754.8125])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-76815.6172,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0., -367279.])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -222348.8594])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -641200.1250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-260485.8906,       0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -565340.6250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -205472.3750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-156573.0625,       0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -134184.8125])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -394247.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -291051.8125])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-71123.4844,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([-177454.2812,       0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -357598.4375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -172234.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -214656.3438])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -337627.2188])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -74577.6406])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-172058.9375,       0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([-135586.4062,       0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -533870.1250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -391192.3438])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-255297.8750,       0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -286248.6562])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -45978.4219])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -70089.9062])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-9147.1934,     0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([     0.0000, -34064.6875])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -450102.9375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-258649.1875,       0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -158553.4844])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -135706.5938])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -506760.0625])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -25029.3594])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([    0.0000, -5814.3721])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -302479.9062])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-35952.1484,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# average loss:  142003.03359375
# accuracy:  0 %
# Train Epoche 4: 100% [==========>]	 accuracy: 100.000000, loss: 0.00000025new epoch 4
# prediction tensor([      0.0000, -341094.1250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -367893.4375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -451601.4375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -24357.3789])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -565261.8750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -367177.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -770680.7500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-84082.6719,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -638690.5000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0., -329663.])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-14521.2578,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -243072.3906])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -486829.3125])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -379118.3125])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([     0.0000, -69405.8984])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-110919.7422,       0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -424996.8750])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -284283.6250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -407700.6562])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -498936.9062])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -114420.9531])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-78521.3438,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([     0.0000, -76205.7188])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -661116.1875])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0., -571437.])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-72965.2344,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -399121.5625])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -221656.4375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -225421.5625])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -115716.9375])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -166397.8438])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -549618.2500])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([-83101.9141,      0.0000])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([1]))
# prediction tensor([      0.0000, -232480.5625])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -280158.3438])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -617274.6250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -151540.1250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -218377.1250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -423090.1250])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# prediction tensor([      0.0000, -146921.4062])
# prediction torch.return_types.max(
# values=tensor([0.]),
# indices=tensor([0]))
# average loss:  186502.82294921874
# accuracy:  0 %

# %% [markdown]
# Dog vs. Cats with a tensorflow model (original from the book)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy import io
import torch 
import os
from sklearn import linear_model


rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [12, 12]

# %%
# dogs vs. cats
dogdata_w_mat = io.loadmat(os.path.join('..','DATA','dogData_w.mat'))
catdata_w_mat = io.loadmat(os.path.join('..','DATA','catData_w.mat'))

dog_wave = dogdata_w_mat['dog_wave']
cat_wave = catdata_w_mat['cat_wave']

CD = np.concatenate((dog_wave,cat_wave),axis=1)

train = np.concatenate((dog_wave[:,:60],cat_wave[:,:60]),axis=1)
test = np.concatenate((dog_wave[:,60:80],cat_wave[:,60:80]),axis=1)
label = np.repeat(np.array([1,-1]),60)

A = label @ np.linalg.pinv(train)
test_labels = np.sign(A@test)

# %%
lasso = linear_model.Lasso().fit(train.T,label)
A_lasso = lasso.coef_
test_labels_lasso = np.sign(A_lasso@test)

# %%
fig,axs = plt.subplots(4,1)
axs[0].bar(range(len(test_labels)),test_labels)
axs[1].bar(range(len(A)),A)
axs[2].bar(range(len(test_labels_lasso)),test_labels_lasso)
axs[3].bar(range(len(A_lasso)),A_lasso)


plt.show()

# %%
fig,axs = plt.subplots(2,2)
axs = axs.reshape(-1)
A2 = np.flipud(np.reshape(A,(32,32)))
A2_lasso = np.flipud(np.reshape(A_lasso,(32,32)))
axs[0].pcolor(np.rot90(A2),cmap='gray')
axs[1].pcolor(np.rot90(A2_lasso),cmap='gray')


plt.show()
