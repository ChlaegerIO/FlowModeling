# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import Dataset

# %%
# load and process data 
#1: (https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#datasets-dataloaders)
import os
from torchvision.io import read_image

#2: manually load and convert to torch tensor
from PIL import Image
from torchvision import transforms
from os import listdir

# read one video
import pylab          # play video
import imageio        # read video in
filename = 'C:/Users/timok/Documents/Git_bachelor/FlowModeling/Videos/Cu/Cu_Fabio.mp4'
vid = imageio.get_reader(filename,  'ffmpeg')
nums = [10, 187]
print(vid.get_data(10).shape)
for num in nums:
    image = vid.get_data(num)
    fig = pylab.figure()
    fig.suptitle('image #{}'.format(num), fontsize=20)
    pylab.imshow(image)
pylab.show()


normalize = transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])    # normalize around mean with sigma (std)
# crop to resolution 1080x1920 amd transform to tensor
transform = transforms.Compose([transforms.Resize(256), transforms.CenterCrop(256), transforms.ToTensor(), normalize])

#train_data_list = []
#train_data = []
#target_label = []
## open the videos, TODO: not image, but video
#for f in listdir('C:/Users/timok/Documents/Git_bachelor/FlowModeling/Videos/Cu/'):
#    img = Image.open('C:/Users/timok/Documents/Git_bachelor/FlowModeling/Videos/Cu/' + f)
#    img_tensor = transforms(img)
#    img_tensor.unsqueeze_(0)   # save directly in img_tensor with _ at the end (1,3,256,256)
#    # label
#
#    if len(train_data_list) >= 64:
#        train_data.append(torch.stack(train_data_list), target_label)
#        train_data_list = []
#        break
#
# Out:
# (1080, 1920, 3)

# %%
# neural network model
class net(nn.Module):
    def __init__(self):
        super(net, self).__init__()
        # here are layer initialisations
        
    def forward(self, x):
        # here is the forward path

        return x

# %%
# training
